# %% [markdown]
# ### Model 3 --- NetMHCpan1.0_BiLSTM

# %% [markdown]
# ##### 训练模型 peptide填充

# %%
import pandas as pd
import numpy as np

import torch
import task_models
import torch.nn as nn
import torch.optim as optim

import matplotlib.pyplot as plt

'''BLOSUM50'''
BLOSUM50_Matrix = pd.read_table('BLOSUM50_Matrix.txt',sep = '\s+')          #用\s+,如果用\t会让txt中第一列会被当作数据
amino_acid_sort = ['A','R','N','D','C','Q','E','G','H','I','L','K','M','F','P','S','T','W','Y','V','B','J','Z','X']    #X可以用于padding
amino_acid_num = len(amino_acid_sort)
BLOSUM50_Matrix = BLOSUM50_Matrix.loc[amino_acid_sort, amino_acid_sort]     #去掉BLOSUM50中的*

'''训练'''
#参数
pep_len_max = 14
HLA_len = 34

embedding_dim = amino_acid_num
lstm_hidden_size = 16                                   #16 from paper
hidden_size = 60                                        #60 from paper
output_size = 1                                         #a single neroun

epoch_num = 30
learning_rate = 0.0005

fold = 5

#设备
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')       #有GPU就用GPU

loss_val_sum = []           #保存每个epoch中，5个模型平均评估loss之和，用于计算最后的平均结果

#开始 5fold-cv 训练
for f in range(fold):

    #模型
    model = task_models.NetMHCpan_10_BiLSTM(embedding_dim, embedding_dim, lstm_hidden_size, hidden_size, output_size).to(device)

    #优化方式
    loss_fn = nn.MSELoss()                                               #MSE-loss
    optimizer = optim.Adam(model.parameters(), lr = learning_rate)       #Adam优化方式

    train_data_num = [n for n in range(fold)]   #训练数据编号
    train_data_num.pop(f)                       #拿出一组训练数据用于评估，其余用于训练

    loss_ave_train = []         #保存每个epoch的平均训练loss
    loss_ave_val = []           #保存每个epoch的平均评估loss

    #训练30个epoch
    for e in range(epoch_num):

        #训练模型
        loss_all_train = []       #保存1个epoch中每个数据的loss

        #用训练数据训练
        for ff in train_data_num:
            '''提取数据'''
            pep_data = pd.read_csv("data_csv/train_data_fold{}.csv".format(ff),usecols=["peptide","length"]) 
            HLA_data = pd.read_csv("data_csv/train_data_fold{}.csv".format(ff),usecols=["HLA_sequence"]) 
            bind_data = pd.read_csv("data_csv/train_data_fold{}.csv".format(ff),usecols=["label"]) 

            pep_seq, pep_len = np.array(pep_data["peptide"]), np.array(pep_data["length"])
            HLA_seq = np.array(HLA_data["HLA_sequence"])
            bind_label = np.array(bind_data["label"])

            data_num = bind_label.size          #数据数量

            for i in range(data_num):

                '''先编码'''
                pep_code = np.zeros((pep_len_max, amino_acid_num))
                HLA_code = np.zeros((HLA_len, amino_acid_num))

                for j in range(pep_len[i]):
                    pep_code[j,:] = BLOSUM50_Matrix[pep_seq[i][j]]              #先对peptide编码

                for j in range(pep_len[i], pep_len_max):
                    pep_code[j,:] = BLOSUM50_Matrix['X']                        #peptide长度不足14，padding，用X编码 

                for j in range(HLA_len):
                    HLA_code[j,:] = BLOSUM50_Matrix[HLA_seq[i][j]]              #对HLA序列编码
                
                pep_code = pep_code.reshape(-1, 1, embedding_dim)               #lstm input: shape = [seq_length, batch_size, input_size]的张量
                HLA_code = HLA_code.reshape(-1, 1, embedding_dim)               #batch_size = 1

                '''前向传播，得到预测与误差'''
                pep_code = torch.Tensor(pep_code).to(device)                    #输入GPU
                HLA_code = torch.Tensor(HLA_code).to(device)

                target = bind_label[i]
                target = target.reshape(-1,1)
                target = torch.Tensor(target).to(device, dtype = torch.float)   #MSE backward()中要求是float，不是long

                prediction = model(pep_code, HLA_code)                         
                loss = loss_fn(prediction, target)
                loss_all_train.append(loss.item())

                '''后向传播，更新模型参数'''
                optimizer.zero_grad()   #梯度清零
                loss.backward()         #计算梯度
                optimizer.step()        #更新参数

        loss_ave_train.append(np.mean(loss_all_train))
        print('epoch-{} training finished , loss_ave_train = {:.4f}'.format(e+1, np.mean(loss_all_train)))


        #用剩余的一组数据评估模型
        loss_all_val = []       #保存1个epoch中每个数据的loss

        '''提取数据'''
        pep_data = pd.read_csv("data_csv/train_data_fold{}.csv".format(f),usecols=["peptide","length"]) 
        HLA_data = pd.read_csv("data_csv/train_data_fold{}.csv".format(f),usecols=["HLA_sequence"]) 
        bind_data = pd.read_csv("data_csv/train_data_fold{}.csv".format(f),usecols=["label"]) 

        pep_seq, pep_len, pep_len_max= np.array(pep_data["peptide"]), np.array(pep_data["length"]), 14
        HLA_seq, HLA_len = np.array(HLA_data["HLA_sequence"]), 34
        bind_label = np.array(bind_data["label"])

        data_num = bind_label.size          #数据数量

        for i in range(data_num):

            '''先编码'''
            pep_code = np.zeros((pep_len_max, amino_acid_num))
            HLA_code = np.zeros((HLA_len, amino_acid_num))

            for j in range(pep_len[i]):
                pep_code[j,:] = BLOSUM50_Matrix[pep_seq[i][j]]              #先对peptide编码

            for j in range(pep_len[i], pep_len_max):
                pep_code[j,:] = BLOSUM50_Matrix['X']                        #peptide长度不足14，padding，用X编码 

            for j in range(HLA_len):
                HLA_code[j,:] = BLOSUM50_Matrix[HLA_seq[i][j]]              #对HLA序列编码
            
            pep_code = pep_code.reshape(-1, 1, embedding_dim)               #lstm input: shape = [seq_length, batch_size, input_size]的张量
            HLA_code = HLA_code.reshape(-1, 1, embedding_dim)               #batch_size = 1           

            '''前向传播，得到预测与误差'''
            pep_code = torch.Tensor(pep_code).to(device)                    #输入GPU
            HLA_code = torch.Tensor(HLA_code).to(device)

            target = bind_label[i]
            target = target.reshape(-1,1)
            target = torch.Tensor(target).to(device, dtype = torch.float)   #MSE backward()中要求是float，不是long

            prediction = model.forward(pep_code, HLA_code)
            loss = loss_fn(prediction, target)
            loss_all_val.append(loss.item())

        loss_ave_val.append(np.mean(loss_all_val))
        print('epoch-{} testing finished , loss_ave_val = {:.4f}'.format(e+1, np.mean(loss_all_val)))
    
    loss_val_sum += loss_ave_val

    #作图，画出loss-epoch折线
    epoch = [e+1 for e in range(epoch_num)]

    plt.figure(f+1)
    plt.plot(epoch, loss_ave_train, marker='o', markersize=2)
    plt.plot(epoch, loss_ave_val, marker='o', markersize=2)
    plt.ylim(0.05, 0.35)
    plt.legend(['train','val'])
    plt.xlabel('epoch'),plt.ylabel('loss_ave')
    plt.title("fold{} as val_data".format(f))

    #保存当前模型
    torch.save(model, "model/NetMHCpan_10_BiLSTM_fold{}.pkl".format(f))
    print("***get the model NetMHCpan_10_BiLSTM_fold{}***".format(f))
# Out:
# epoch-1 training finished , loss_ave_train = 0.2158
# epoch-1 testing finished , loss_ave_val = 0.1984
# epoch-2 training finished , loss_ave_train = 0.1759
# epoch-2 testing finished , loss_ave_val = 0.1825
# epoch-3 training finished , loss_ave_train = 0.1610
# epoch-3 testing finished , loss_ave_val = 0.1714
# epoch-4 training finished , loss_ave_train = 0.1470
# epoch-4 testing finished , loss_ave_val = 0.1668
# epoch-5 training finished , loss_ave_train = 0.1321
# epoch-5 testing finished , loss_ave_val = 0.1618
# epoch-6 training finished , loss_ave_train = 0.1195
# epoch-6 testing finished , loss_ave_val = 0.1601
# epoch-7 training finished , loss_ave_train = 0.1089
# epoch-7 testing finished , loss_ave_val = 0.1564
# epoch-8 training finished , loss_ave_train = 0.1022
# epoch-8 testing finished , loss_ave_val = 0.1554
# epoch-9 training finished , loss_ave_train = 0.0941
# epoch-9 testing finished , loss_ave_val = 0.1508
# epoch-10 training finished , loss_ave_train = 0.0867
# epoch-10 testing finished , loss_ave_val = 0.1475
# epoch-11 training finished , loss_ave_train = 0.0808
# epoch-11 testing finished , loss_ave_val = 0.1476
# epoch-12 training finished , loss_ave_train = 0.0764
# epoch-12 testing finished , loss_ave_val = 0.1489
# epoch-13 training finished , loss_ave_train = 0.0717
# epoch-13 testing finished , loss_ave_val = 0.1485
# epoch-14 training finished , loss_ave_train = 0.0661
# epoch-14 testing finished , loss_ave_val = 0.1475
# epoch-15 training finished , loss_ave_train = 0.0625
# epoch-15 testing finished , loss_ave_val = 0.1516
# epoch-16 training finished , loss_ave_train = 0.0575
# epoch-16 testing finished , loss_ave_val = 0.1592
# epoch-17 training finished , loss_ave_train = 0.0549
# epoch-17 testing finished , loss_ave_val = 0.1558
# epoch-18 training finished , loss_ave_train = 0.0509
# epoch-18 testing finished , loss_ave_val = 0.1560
# epoch-19 training finished , loss_ave_train = 0.0482
# epoch-19 testing finished , loss_ave_val = 0.1512
# epoch-20 training finished , loss_ave_train = 0.0456
# epoch-20 testing finished , loss_ave_val = 0.1548
# epoch-21 training finished , loss_ave_train = 0.0450
# epoch-21 testing finished , loss_ave_val = 0.1527
# epoch-22 training finished , loss_ave_train = 0.0415
# epoch-22 testing finished , loss_ave_val = 0.1595
# epoch-23 training finished , loss_ave_train = 0.0398
# epoch-23 testing finished , loss_ave_val = 0.1649
# epoch-24 training finished , loss_ave_train = 0.0388
# epoch-24 testing finished , loss_ave_val = 0.1650
# epoch-25 training finished , loss_ave_train = 0.0359
# epoch-25 testing finished , loss_ave_val = 0.1597
# epoch-26 training finished , loss_ave_train = 0.0336
# epoch-26 testing finished , loss_ave_val = 0.1678
# epoch-27 training finished , loss_ave_train = 0.0315
# epoch-27 testing finished , loss_ave_val = 0.1723
# epoch-28 training finished , loss_ave_train = 0.0301
# epoch-28 testing finished , loss_ave_val = 0.1671
# epoch-29 training finished , loss_ave_train = 0.0309
# epoch-29 testing finished , loss_ave_val = 0.1720
# epoch-30 training finished , loss_ave_train = 0.0261
# epoch-30 testing finished , loss_ave_val = 0.1870
# ***get the model NetMHCpan_10_BiLSTM_fold0***
# epoch-1 training finished , loss_ave_train = 0.2111
# epoch-1 testing finished , loss_ave_val = 0.1879
# epoch-2 training finished , loss_ave_train = 0.1729
# epoch-2 testing finished , loss_ave_val = 0.1728
# epoch-3 training finished , loss_ave_train = 0.1581
# epoch-3 testing finished , loss_ave_val = 0.1636
# epoch-4 training finished , loss_ave_train = 0.1457
# epoch-4 testing finished , loss_ave_val = 0.1560
# epoch-5 training finished , loss_ave_train = 0.1344
# epoch-5 testing finished , loss_ave_val = 0.1528
# epoch-6 training finished , loss_ave_train = 0.1243
# epoch-6 testing finished , loss_ave_val = 0.1516
# epoch-7 training finished , loss_ave_train = 0.1148
# epoch-7 testing finished , loss_ave_val = 0.1518
# epoch-8 training finished , loss_ave_train = 0.1060
# epoch-8 testing finished , loss_ave_val = 0.1514
# epoch-9 training finished , loss_ave_train = 0.0982
# epoch-9 testing finished , loss_ave_val = 0.1488
# epoch-10 training finished , loss_ave_train = 0.0911
# epoch-10 testing finished , loss_ave_val = 0.1482
# epoch-11 training finished , loss_ave_train = 0.0847
# epoch-11 testing finished , loss_ave_val = 0.1504
# epoch-12 training finished , loss_ave_train = 0.0792
# epoch-12 testing finished , loss_ave_val = 0.1504
# epoch-13 training finished , loss_ave_train = 0.0738
# epoch-13 testing finished , loss_ave_val = 0.1516
# epoch-14 training finished , loss_ave_train = 0.0696
# epoch-14 testing finished , loss_ave_val = 0.1514
# epoch-15 training finished , loss_ave_train = 0.0653
# epoch-15 testing finished , loss_ave_val = 0.1522
# epoch-16 training finished , loss_ave_train = 0.0611
# epoch-16 testing finished , loss_ave_val = 0.1525
# epoch-17 training finished , loss_ave_train = 0.0575
# epoch-17 testing finished , loss_ave_val = 0.1599
# epoch-18 training finished , loss_ave_train = 0.0535
# epoch-18 testing finished , loss_ave_val = 0.1610
# epoch-19 training finished , loss_ave_train = 0.0492
# epoch-19 testing finished , loss_ave_val = 0.1600
# epoch-20 training finished , loss_ave_train = 0.0464
# epoch-20 testing finished , loss_ave_val = 0.1582
# epoch-21 training finished , loss_ave_train = 0.0436
# epoch-21 testing finished , loss_ave_val = 0.1627
# epoch-22 training finished , loss_ave_train = 0.0409
# epoch-22 testing finished , loss_ave_val = 0.1645
# epoch-23 training finished , loss_ave_train = 0.0379
# epoch-23 testing finished , loss_ave_val = 0.1667
# epoch-24 training finished , loss_ave_train = 0.0365
# epoch-24 testing finished , loss_ave_val = 0.1631
# epoch-25 training finished , loss_ave_train = 0.0344
# epoch-25 testing finished , loss_ave_val = 0.1704
# epoch-26 training finished , loss_ave_train = 0.0356
# epoch-26 testing finished , loss_ave_val = 0.1678
# epoch-27 training finished , loss_ave_train = 0.0312
# epoch-27 testing finished , loss_ave_val = 0.1714
# epoch-28 training finished , loss_ave_train = 0.0305
# epoch-28 testing finished , loss_ave_val = 0.1695
# epoch-29 training finished , loss_ave_train = 0.0292
# epoch-29 testing finished , loss_ave_val = 0.1763
# epoch-30 training finished , loss_ave_train = 0.0280
# epoch-30 testing finished , loss_ave_val = 0.1695
# ***get the model NetMHCpan_10_BiLSTM_fold1***
# epoch-1 training finished , loss_ave_train = 0.2129
# epoch-1 testing finished , loss_ave_val = 0.2063
# epoch-2 training finished , loss_ave_train = 0.1699
# epoch-2 testing finished , loss_ave_val = 0.1888
# epoch-3 training finished , loss_ave_train = 0.1544
# epoch-3 testing finished , loss_ave_val = 0.1808
# epoch-4 training finished , loss_ave_train = 0.1427
# epoch-4 testing finished , loss_ave_val = 0.1753
# epoch-5 training finished , loss_ave_train = 0.1321
# epoch-5 testing finished , loss_ave_val = 0.1713
# epoch-6 training finished , loss_ave_train = 0.1228
# epoch-6 testing finished , loss_ave_val = 0.1716
# epoch-7 training finished , loss_ave_train = 0.1140
# epoch-7 testing finished , loss_ave_val = 0.1689
# epoch-8 training finished , loss_ave_train = 0.1065
# epoch-8 testing finished , loss_ave_val = 0.1643
# epoch-9 training finished , loss_ave_train = 0.0994
# epoch-9 testing finished , loss_ave_val = 0.1634
# epoch-10 training finished , loss_ave_train = 0.0930
# epoch-10 testing finished , loss_ave_val = 0.1645
# epoch-11 training finished , loss_ave_train = 0.0870
# epoch-11 testing finished , loss_ave_val = 0.1648
# epoch-12 training finished , loss_ave_train = 0.0815
# epoch-12 testing finished , loss_ave_val = 0.1623
# epoch-13 training finished , loss_ave_train = 0.0764
# epoch-13 testing finished , loss_ave_val = 0.1640
# epoch-14 training finished , loss_ave_train = 0.0718
# epoch-14 testing finished , loss_ave_val = 0.1624
# epoch-15 training finished , loss_ave_train = 0.0677
# epoch-15 testing finished , loss_ave_val = 0.1643
# epoch-16 training finished , loss_ave_train = 0.0635
# epoch-16 testing finished , loss_ave_val = 0.1659
# epoch-17 training finished , loss_ave_train = 0.0597
# epoch-17 testing finished , loss_ave_val = 0.1688
# epoch-18 training finished , loss_ave_train = 0.0561
# epoch-18 testing finished , loss_ave_val = 0.1690
# epoch-19 training finished , loss_ave_train = 0.0526
# epoch-19 testing finished , loss_ave_val = 0.1747
# epoch-20 training finished , loss_ave_train = 0.0497
# epoch-20 testing finished , loss_ave_val = 0.1752
# epoch-21 training finished , loss_ave_train = 0.0463
# epoch-21 testing finished , loss_ave_val = 0.1759
# epoch-22 training finished , loss_ave_train = 0.0432
# epoch-22 testing finished , loss_ave_val = 0.1797
# epoch-23 training finished , loss_ave_train = 0.0406
# epoch-23 testing finished , loss_ave_val = 0.1754
# epoch-24 training finished , loss_ave_train = 0.0382
# epoch-24 testing finished , loss_ave_val = 0.1826
# epoch-25 training finished , loss_ave_train = 0.0359
# epoch-25 testing finished , loss_ave_val = 0.1820
# epoch-26 training finished , loss_ave_train = 0.0346
# epoch-26 testing finished , loss_ave_val = 0.1847
# epoch-27 training finished , loss_ave_train = 0.0323
# epoch-27 testing finished , loss_ave_val = 0.1854
# epoch-28 training finished , loss_ave_train = 0.0313
# epoch-28 testing finished , loss_ave_val = 0.1945
# epoch-29 training finished , loss_ave_train = 0.0286
# epoch-29 testing finished , loss_ave_val = 0.1930
# epoch-30 training finished , loss_ave_train = 0.0272
# epoch-30 testing finished , loss_ave_val = 0.1941
# ***get the model NetMHCpan_10_BiLSTM_fold2***
# epoch-1 training finished , loss_ave_train = 0.2086
# epoch-1 testing finished , loss_ave_val = 0.1824
# epoch-2 training finished , loss_ave_train = 0.1706
# epoch-2 testing finished , loss_ave_val = 0.1726
# epoch-3 training finished , loss_ave_train = 0.1555
# epoch-3 testing finished , loss_ave_val = 0.1663
# epoch-4 training finished , loss_ave_train = 0.1448
# epoch-4 testing finished , loss_ave_val = 0.1613
# epoch-5 training finished , loss_ave_train = 0.1353
# epoch-5 testing finished , loss_ave_val = 0.1593
# epoch-6 training finished , loss_ave_train = 0.1263
# epoch-6 testing finished , loss_ave_val = 0.1571
# epoch-7 training finished , loss_ave_train = 0.1188
# epoch-7 testing finished , loss_ave_val = 0.1566
# epoch-8 training finished , loss_ave_train = 0.1115
# epoch-8 testing finished , loss_ave_val = 0.1543
# epoch-9 training finished , loss_ave_train = 0.1060
# epoch-9 testing finished , loss_ave_val = 0.1526
# epoch-10 training finished , loss_ave_train = 0.0986
# epoch-10 testing finished , loss_ave_val = 0.1551
# epoch-11 training finished , loss_ave_train = 0.0927
# epoch-11 testing finished , loss_ave_val = 0.1582
# epoch-12 training finished , loss_ave_train = 0.0873
# epoch-12 testing finished , loss_ave_val = 0.1598
# epoch-13 training finished , loss_ave_train = 0.0817
# epoch-13 testing finished , loss_ave_val = 0.1696
# epoch-14 training finished , loss_ave_train = 0.0768
# epoch-14 testing finished , loss_ave_val = 0.1704
# epoch-15 training finished , loss_ave_train = 0.0730
# epoch-15 testing finished , loss_ave_val = 0.1711
# epoch-16 training finished , loss_ave_train = 0.0668
# epoch-16 testing finished , loss_ave_val = 0.1737
# epoch-17 training finished , loss_ave_train = 0.0629
# epoch-17 testing finished , loss_ave_val = 0.1817
# epoch-18 training finished , loss_ave_train = 0.0595
# epoch-18 testing finished , loss_ave_val = 0.1828
# epoch-19 training finished , loss_ave_train = 0.0565
# epoch-19 testing finished , loss_ave_val = 0.1824
# epoch-20 training finished , loss_ave_train = 0.0525
# epoch-20 testing finished , loss_ave_val = 0.1822
# epoch-21 training finished , loss_ave_train = 0.0498
# epoch-21 testing finished , loss_ave_val = 0.1863
# epoch-22 training finished , loss_ave_train = 0.0469
# epoch-22 testing finished , loss_ave_val = 0.1875
# epoch-23 training finished , loss_ave_train = 0.0448
# epoch-23 testing finished , loss_ave_val = 0.1905
# epoch-24 training finished , loss_ave_train = 0.0418
# epoch-24 testing finished , loss_ave_val = 0.1905
# epoch-25 training finished , loss_ave_train = 0.0391
# epoch-25 testing finished , loss_ave_val = 0.1975
# epoch-26 training finished , loss_ave_train = 0.0378
# epoch-26 testing finished , loss_ave_val = 0.2042
# epoch-27 training finished , loss_ave_train = 0.0354
# epoch-27 testing finished , loss_ave_val = 0.2003
# epoch-28 training finished , loss_ave_train = 0.0331
# epoch-28 testing finished , loss_ave_val = 0.1998
# epoch-29 training finished , loss_ave_train = 0.0324
# epoch-29 testing finished , loss_ave_val = 0.2048
# epoch-30 training finished , loss_ave_train = 0.0308
# epoch-30 testing finished , loss_ave_val = 0.2041
# ***get the model NetMHCpan_10_BiLSTM_fold3***
# epoch-1 training finished , loss_ave_train = 0.2108
# epoch-1 testing finished , loss_ave_val = 0.1849
# epoch-2 training finished , loss_ave_train = 0.1667
# epoch-2 testing finished , loss_ave_val = 0.1786
# epoch-3 training finished , loss_ave_train = 0.1533
# epoch-3 testing finished , loss_ave_val = 0.1729
# epoch-4 training finished , loss_ave_train = 0.1410
# epoch-4 testing finished , loss_ave_val = 0.1664
# epoch-5 training finished , loss_ave_train = 0.1293
# epoch-5 testing finished , loss_ave_val = 0.1640
# epoch-6 training finished , loss_ave_train = 0.1185
# epoch-6 testing finished , loss_ave_val = 0.1631
# epoch-7 training finished , loss_ave_train = 0.1093
# epoch-7 testing finished , loss_ave_val = 0.1626
# epoch-8 training finished , loss_ave_train = 0.1020
# epoch-8 testing finished , loss_ave_val = 0.1658
# epoch-9 training finished , loss_ave_train = 0.0956
# epoch-9 testing finished , loss_ave_val = 0.1693
# epoch-10 training finished , loss_ave_train = 0.0897
# epoch-10 testing finished , loss_ave_val = 0.1704
# epoch-11 training finished , loss_ave_train = 0.0856
# epoch-11 testing finished , loss_ave_val = 0.1716
# epoch-12 training finished , loss_ave_train = 0.0807
# epoch-12 testing finished , loss_ave_val = 0.1758
# epoch-13 training finished , loss_ave_train = 0.0766
# epoch-13 testing finished , loss_ave_val = 0.1759
# epoch-14 training finished , loss_ave_train = 0.0728
# epoch-14 testing finished , loss_ave_val = 0.1755
# epoch-15 training finished , loss_ave_train = 0.0679
# epoch-15 testing finished , loss_ave_val = 0.1759
# epoch-16 training finished , loss_ave_train = 0.0657
# epoch-16 testing finished , loss_ave_val = 0.1756
# epoch-17 training finished , loss_ave_train = 0.0613
# epoch-17 testing finished , loss_ave_val = 0.1784
# epoch-18 training finished , loss_ave_train = 0.0589
# epoch-18 testing finished , loss_ave_val = 0.1761
# epoch-19 training finished , loss_ave_train = 0.0538
# epoch-19 testing finished , loss_ave_val = 0.1782
# epoch-20 training finished , loss_ave_train = 0.0509
# epoch-20 testing finished , loss_ave_val = 0.1781
# epoch-21 training finished , loss_ave_train = 0.0469
# epoch-21 testing finished , loss_ave_val = 0.1792
# epoch-22 training finished , loss_ave_train = 0.0448
# epoch-22 testing finished , loss_ave_val = 0.1786
# epoch-23 training finished , loss_ave_train = 0.0415
# epoch-23 testing finished , loss_ave_val = 0.1803
# epoch-24 training finished , loss_ave_train = 0.0387
# epoch-24 testing finished , loss_ave_val = 0.1831
# epoch-25 training finished , loss_ave_train = 0.0360
# epoch-25 testing finished , loss_ave_val = 0.1819
# epoch-26 training finished , loss_ave_train = 0.0357
# epoch-26 testing finished , loss_ave_val = 0.1805
# epoch-27 training finished , loss_ave_train = 0.0329
# epoch-27 testing finished , loss_ave_val = 0.1816
# epoch-28 training finished , loss_ave_train = 0.0304
# epoch-28 testing finished , loss_ave_val = 0.1820
# epoch-29 training finished , loss_ave_train = 0.0314
# epoch-29 testing finished , loss_ave_val = 0.1829
# epoch-30 training finished , loss_ave_train = 0.0290
# epoch-30 testing finished , loss_ave_val = 0.1846
# ***get the model NetMHCpan_10_BiLSTM_fold4***

# %%
#平均评估loss
epoch = [e+1 for e in range(epoch_num)]
loss_val_ave = []
for e in range(epoch_num):
    sum = 0
    for n in range(fold):
        sum += loss_val_sum[n*epoch_num + e]
    loss_val_ave.append(sum/fold)
plt.figure(fold+1)
plt.plot(epoch, loss_val_ave, marker='o', markersize=3)
plt.xlabel('epoch'),plt.ylabel('loss')
plt.title("model's validation result")
# Out:
# Text(0.5, 1.0, "model's validation result")

# %% [markdown]
# ##### 在其他data_set上的accuracy

# %%
#independent_set
import pandas as pd
import numpy as np
import torch

'''BLOSUM50'''
BLOSUM50_Matrix = pd.read_table('BLOSUM50_Matrix.txt',sep = '\s+')          #用\s+,如果用\t会让txt中第一列会被当作数据
amino_acid_sort = ['A','R','N','D','C','Q','E','G','H','I','L','K','M','F','P','S','T','W','Y','V','B','J','Z','X']    #X可以用于padding
amino_acid_num = len(amino_acid_sort)
BLOSUM50_Matrix = BLOSUM50_Matrix.loc[amino_acid_sort, amino_acid_sort]     #去掉BLOSUM50中的*

#参数
pep_len_max = 14
HLA_len = 34

embedding_dim = amino_acid_num
lstm_hidden_size = 16                                   #16 from paper
hidden_size = 60                                        #60 from paper
output_size = 1                                         #a single neroun

fold = 5

#设备
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')       #有GPU就用GPU

'''提取数据'''
pep_data = pd.read_csv("data_csv/independent_set2.csv",usecols=["peptide","length"]) 
HLA_data = pd.read_csv("data_csv/independent_set2.csv",usecols=["HLA_sequence"]) 
bind_data = pd.read_csv("data_csv/independent_set2.csv",usecols=["label"]) 

pep_seq, pep_len, pep_len_max= np.array(pep_data["peptide"]), np.array(pep_data["length"]), 14
HLA_seq, HLA_len = np.array(HLA_data["HLA_sequence"]), 34
bind_label = np.array(bind_data["label"])

data_num = bind_label.size          #数据数量

'''加载模型'''
use_model = torch.load("model/NetMHCpan_10_BiLSTM_fold2.pkl")

'''预测'''
pre_result = np.zeros(data_num)

for i in range(data_num):

    '''先编码'''
    pep_code = np.zeros((pep_len_max, amino_acid_num))
    HLA_code = np.zeros((HLA_len, amino_acid_num))

    for j in range(pep_len[i]):
        pep_code[j,:] = BLOSUM50_Matrix[pep_seq[i][j]]              #先对peptide编码

    for j in range(pep_len[i], pep_len_max):
        pep_code[j,:] = BLOSUM50_Matrix['X']                        #peptide长度不足14，padding，用X编码 

    for j in range(HLA_len):
        HLA_code[j,:] = BLOSUM50_Matrix[HLA_seq[i][j]]              #最后对HLA序列编码，放在后面
            
    pep_code = pep_code.reshape(-1, 1, embedding_dim)               #lstm input: shape = [seq_length, batch_size, input_size]的张量
    HLA_code = HLA_code.reshape(-1, 1, embedding_dim)               #batch_size = 1           

    '''前向传播，得到预测'''
    pep_code = torch.Tensor(pep_code).to(device)                    #输入GPU
    HLA_code = torch.Tensor(HLA_code).to(device)

    target = bind_label[i]
    target = target.reshape(-1,1)
    target = torch.Tensor(target).to(device, dtype = torch.float)   #MSE backward()中要求是float，不是long

    prediction = use_model(pep_code, HLA_code)
    pre_result[i] = prediction.item()

'''probability--->binding(1) or non-binding(0)'''
pre_result[pre_result >= 0.5] = 1
pre_result[pre_result < 0.5] = 0

'''prediction与label比较'''
pre_result[pre_result != bind_label] = 0    #用pre_result保存比较结果
pre_result[pre_result == bind_label] = 1

correct_num = np.sum(pre_result)
accuracy = correct_num/data_num
print("accuracy on independent_set is {:.4f}".format(accuracy))
# Out:
# accuracy on independent_set is 0.8789

# %%
#external_set
'''BLOSUM50'''
BLOSUM50_Matrix = pd.read_table('BLOSUM50_Matrix.txt',sep = '\s+')          #用\s+,如果用\t会让txt中第一列会被当作数据
amino_acid_sort = ['A','R','N','D','C','Q','E','G','H','I','L','K','M','F','P','S','T','W','Y','V','B','J','Z','X']    #X可以用于padding
amino_acid_num = len(amino_acid_sort)
BLOSUM50_Matrix = BLOSUM50_Matrix.loc[amino_acid_sort, amino_acid_sort]     #去掉BLOSUM50中的*

'''提取数据'''
pep_data = pd.read_csv("data_csv/external_set2.csv",usecols=["peptide","length"]) 
HLA_data = pd.read_csv("data_csv/external_set2.csv",usecols=["HLA_sequence"]) 
bind_data = pd.read_csv("data_csv/external_set2.csv",usecols=["label"]) 

pep_seq, pep_len, pep_len_max= np.array(pep_data["peptide"]), np.array(pep_data["length"]), 14
HLA_seq, HLA_len = np.array(HLA_data["HLA_sequence"]), 34
bind_label = np.array(bind_data["label"])

data_num = bind_label.size          #数据数量

'''加载模型'''
use_model = torch.load("model/NetMHCpan_10_BiLSTM_fold2.pkl")

'''预测'''
pre_result = np.zeros(data_num)

for i in range(data_num):

    '''先编码'''
    pep_code = np.zeros((pep_len_max, amino_acid_num))
    HLA_code = np.zeros((HLA_len, amino_acid_num))

    for j in range(pep_len[i]):
        pep_code[j,:] = BLOSUM50_Matrix[pep_seq[i][j]]              #先对peptide编码

    for j in range(pep_len[i], pep_len_max):
        pep_code[j,:] = BLOSUM50_Matrix['X']                        #peptide长度不足14，padding，用X编码 

    for j in range(HLA_len):
        HLA_code[j,:] = BLOSUM50_Matrix[HLA_seq[i][j]]              #最后对HLA序列编码，放在后面
            
    pep_code = pep_code.reshape(-1, 1, embedding_dim)               #lstm input: shape = [seq_length, batch_size, input_size]的张量
    HLA_code = HLA_code.reshape(-1, 1, embedding_dim)               #batch_size = 1           

    '''前向传播，得到预测'''
    pep_code = torch.Tensor(pep_code).to(device)                    #输入GPU
    HLA_code = torch.Tensor(HLA_code).to(device)

    target = bind_label[i]
    target = target.reshape(-1,1)
    target = torch.Tensor(target).to(device, dtype = torch.float)   #MSE backward()中要求是float，不是long

    prediction = use_model(pep_code, HLA_code)
    pre_result[i] = prediction.item()

'''probability--->binding(1) or non-binding(0)'''
pre_result[pre_result >= 0.5] = 1
pre_result[pre_result < 0.5] = 0

'''prediction与label比较'''
pre_result[pre_result != bind_label] = 0    #用pre_result保存比较结果
pre_result[pre_result == bind_label] = 1

correct_num = np.sum(pre_result)
accuracy = correct_num/data_num
print("accuracy on external_set is {}".format(accuracy))
# Out:
# accuracy on external_set is 0.882

# %% [markdown]
# fold2's accuracy is the highest, and its train_loss and val_loss are good
