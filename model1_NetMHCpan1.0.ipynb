# %% [markdown]
# ### Model 1 --- NetMHCpan1.0

# %% [markdown]
# ##### 训练模型

# %%
import pandas as pd
import numpy as np

import torch
import task_models
import torch.nn as nn
import torch.optim as optim

import matplotlib.pyplot as plt

'''BLOSUM50'''
BLOSUM50_Matrix = pd.read_table('BLOSUM50_Matrix.txt',sep = '\s+')          #用\s+,如果用\t会让txt中第一列会被当作数据
amino_acid_sort = ['A','R','N','D','C','Q','E','G','H','I','L','K','M','F','P','S','T','W','Y','V','B','J','Z','X']    #X可以用于padding
amino_acid_num = len(amino_acid_sort)
BLOSUM50_Matrix = BLOSUM50_Matrix.loc[amino_acid_sort, amino_acid_sort]     #去掉BLOSUM50中的*

'''训练'''
#参数
pep_len_max = 14
HLA_len = 34

input_size = (pep_len_max + HLA_len) * amino_acid_num   #pHLA编码长度
hidden_size = 60                                        #22-86 from paper
output_size = 1                                         #a single neroun

fold = 5
epoch_num = 30
learning_rate = 0.001

#设备
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')       #有GPU就用GPU

loss_val_sum = []           #保存每个epoch中，5个模型平均评估loss之和，用于计算最后的平均结果

#开始 5fold-cv 训练
for f in range(fold):

    #模型
    model = task_models.NetMHCpan_10(input_size, hidden_size, output_size).to(device)

    #优化方式
    loss_fn = nn.MSELoss()                                               #MSE-loss
    optimizer = optim.Adam(model.parameters(), lr = learning_rate)       #Adam优化方式

    train_data_num = [n for n in range(fold)]   #训练数据编号
    train_data_num.pop(f)                       #拿出一组训练数据用于评估，其余用于训练

    loss_ave_train = []         #保存每个epoch的平均训练loss
    loss_ave_val = []           #保存每个epoch的平均评估loss

    #训练30个epoch
    for e in range(epoch_num):

        #训练模型
        loss_all_train = []       #保存1个epoch中每个数据的loss

        #用训练数据训练
        for ff in train_data_num:
            '''提取数据'''
            pep_data = pd.read_csv("data_csv/train_data_fold{}.csv".format(ff),usecols=["peptide","length"]) 
            HLA_data = pd.read_csv("data_csv/train_data_fold{}.csv".format(ff),usecols=["HLA_sequence"]) 
            bind_data = pd.read_csv("data_csv/train_data_fold{}.csv".format(ff),usecols=["label"]) 

            pep_seq, pep_len = np.array(pep_data["peptide"]), np.array(pep_data["length"])
            HLA_seq = np.array(HLA_data["HLA_sequence"])
            bind_label = np.array(bind_data["label"])

            data_num = bind_label.size          #数据数量

            for i in range(data_num):

                '''编码'''
                pHLA_code = np.zeros((HLA_len+pep_len_max, amino_acid_num))

                for j in range(pep_len[i]):
                    pHLA_code[j,:] = BLOSUM50_Matrix[pep_seq[i][j]]             #先对peptide编码

                for j in range(pep_len[i], pep_len_max):
                    pHLA_code[j,:] = BLOSUM50_Matrix['X']                       #peptide长度不足14，padding，用X编码 

                for j in range(HLA_len):
                    pHLA_code[j+pep_len_max,:] = BLOSUM50_Matrix[HLA_seq[i][j]] #最后对HLA序列编码，放在后面
                
                pHLA_code = pHLA_code.reshape(-1, input_size)                   #转为1*1152数组

                '''前向传播，得到预测与误差'''
                pHLA_code = torch.Tensor(pHLA_code).to(device)                  #输入GPU
                target = bind_label[i]
                target = target.reshape(-1,1)
                target = torch.Tensor(target).to(device, dtype = torch.float)   #MSE backward()中要求是float，不是long

                prediction = model(pHLA_code)
                loss = loss_fn(prediction, target)
                loss_all_train.append(loss.item())

            #    print(prediction)
            #    print(target)
            #    print(loss)

                '''后向传播，更新模型参数'''
                optimizer.zero_grad()   #梯度清零
                loss.backward()         #计算梯度
                optimizer.step()        #更新参数

        loss_ave_train.append(np.mean(loss_all_train))          #对所有数据的loss取平均
        print('epoch-{} training finished , loss_ave_train = {:.4f}'.format(e+1, np.mean(loss_all_train)))


        #用剩余的一组数据评估模型
        loss_all_val = []       #保存1个epoch中每个数据的loss

        '''提取数据'''
        pep_data = pd.read_csv("data_csv/train_data_fold{}.csv".format(f),usecols=["peptide","length"]) 
        HLA_data = pd.read_csv("data_csv/train_data_fold{}.csv".format(f),usecols=["HLA_sequence"]) 
        bind_data = pd.read_csv("data_csv/train_data_fold{}.csv".format(f),usecols=["label"]) 

        pep_seq, pep_len, pep_len_max= np.array(pep_data["peptide"]), np.array(pep_data["length"]), 14
        HLA_seq, HLA_len = np.array(HLA_data["HLA_sequence"]), 34
        bind_label = np.array(bind_data["label"])

        data_num = bind_label.size          #数据数量

        for i in range(data_num):

            '''编码'''
            pHLA_code = np.zeros((HLA_len+pep_len_max, amino_acid_num))

            for j in range(pep_len[i]):
                pHLA_code[j,:] = BLOSUM50_Matrix[pep_seq[i][j]]             #先对peptide编码

            for j in range(pep_len[i], pep_len_max):
                pHLA_code[j,:] = BLOSUM50_Matrix['X']                       #peptide长度不足14，padding，用X编码 

            for j in range(HLA_len):
                pHLA_code[j+pep_len_max,:] = BLOSUM50_Matrix[HLA_seq[i][j]] #最后对HLA序列编码，放在后面
                
            pHLA_code = pHLA_code.reshape(-1, input_size)                   #转为1*1152数组

            '''前向传播，得到预测与误差'''
            pHLA_code = torch.Tensor(pHLA_code).to(device)                  #输入GPU
            target = bind_label[i]
            target = target.reshape(-1,1)
            target = torch.Tensor(target).to(device, dtype = torch.float)   #MSE backward()中要求是float，不是long

            prediction = model(pHLA_code)
            loss = loss_fn(prediction, target)
            loss_all_val.append(loss.item())

        loss_ave_val.append(np.mean(loss_all_val))
        print('epoch-{} testing finished , loss_ave_val = {:.4f}'.format(e+1, np.mean(loss_all_val)))
    
    loss_val_sum += loss_ave_val

    #作图，画出loss-epoch折线
    epoch = [e+1 for e in range(epoch_num)]

    plt.figure(f+1)
    plt.plot(epoch, loss_ave_train, marker='o', markersize=2)
    plt.plot(epoch, loss_ave_val, marker='o', markersize=2)
    plt.ylim(0.05, 0.35)
    plt.legend(['train','val'])
    plt.xlabel('epoch'),plt.ylabel('loss_ave')
    plt.title("fold{} as val_data".format(f))

    #保存当前模型
    torch.save(model, "model/NetMHCpan_10_fold{}.pkl".format(f))
    print("***get the model NetMHCpan_10_fold{}***".format(f))
# Out:
# epoch-1 training finished , loss_ave_train = 0.2503
# epoch-1 testing finished , loss_ave_val = 0.1995
# epoch-2 training finished , loss_ave_train = 0.2063
# epoch-2 testing finished , loss_ave_val = 0.1898
# epoch-3 training finished , loss_ave_train = 0.1941
# epoch-3 testing finished , loss_ave_val = 0.1873
# epoch-4 training finished , loss_ave_train = 0.1882
# epoch-4 testing finished , loss_ave_val = 0.1864
# epoch-5 training finished , loss_ave_train = 0.1829
# epoch-5 testing finished , loss_ave_val = 0.1855
# epoch-6 training finished , loss_ave_train = 0.1796
# epoch-6 testing finished , loss_ave_val = 0.1850
# epoch-7 training finished , loss_ave_train = 0.1766
# epoch-7 testing finished , loss_ave_val = 0.1846
# epoch-8 training finished , loss_ave_train = 0.1743
# epoch-8 testing finished , loss_ave_val = 0.1848
# epoch-9 training finished , loss_ave_train = 0.1725
# epoch-9 testing finished , loss_ave_val = 0.1848
# epoch-10 training finished , loss_ave_train = 0.1709
# epoch-10 testing finished , loss_ave_val = 0.1852
# epoch-11 training finished , loss_ave_train = 0.1696
# epoch-11 testing finished , loss_ave_val = 0.1875
# epoch-12 training finished , loss_ave_train = 0.1684
# epoch-12 testing finished , loss_ave_val = 0.1877
# epoch-13 training finished , loss_ave_train = 0.1674
# epoch-13 testing finished , loss_ave_val = 0.1881
# epoch-14 training finished , loss_ave_train = 0.1666
# epoch-14 testing finished , loss_ave_val = 0.1867
# epoch-15 training finished , loss_ave_train = 0.1657
# epoch-15 testing finished , loss_ave_val = 0.1873
# epoch-16 training finished , loss_ave_train = 0.1648
# epoch-16 testing finished , loss_ave_val = 0.1873
# epoch-17 training finished , loss_ave_train = 0.1640
# epoch-17 testing finished , loss_ave_val = 0.1875
# epoch-18 training finished , loss_ave_train = 0.1631
# epoch-18 testing finished , loss_ave_val = 0.1876
# epoch-19 training finished , loss_ave_train = 0.1624
# epoch-19 testing finished , loss_ave_val = 0.1878
# epoch-20 training finished , loss_ave_train = 0.1618
# epoch-20 testing finished , loss_ave_val = 0.1880
# epoch-21 training finished , loss_ave_train = 0.1613
# epoch-21 testing finished , loss_ave_val = 0.1881
# epoch-22 training finished , loss_ave_train = 0.1608
# epoch-22 testing finished , loss_ave_val = 0.1884
# epoch-23 training finished , loss_ave_train = 0.1603
# epoch-23 testing finished , loss_ave_val = 0.1885
# epoch-24 training finished , loss_ave_train = 0.1598
# epoch-24 testing finished , loss_ave_val = 0.1888
# epoch-25 training finished , loss_ave_train = 0.1594
# epoch-25 testing finished , loss_ave_val = 0.1890
# epoch-26 training finished , loss_ave_train = 0.1590
# epoch-26 testing finished , loss_ave_val = 0.1893
# epoch-27 training finished , loss_ave_train = 0.1587
# epoch-27 testing finished , loss_ave_val = 0.1897
# epoch-28 training finished , loss_ave_train = 0.1583
# epoch-28 testing finished , loss_ave_val = 0.1899
# epoch-29 training finished , loss_ave_train = 0.1580
# epoch-29 testing finished , loss_ave_val = 0.1902
# epoch-30 training finished , loss_ave_train = 0.1576
# epoch-30 testing finished , loss_ave_val = 0.1904
# ***get the model NetMHCpan_10_fold0***
# epoch-1 training finished , loss_ave_train = 0.2456
# epoch-1 testing finished , loss_ave_val = 0.1981
# epoch-2 training finished , loss_ave_train = 0.2004
# epoch-2 testing finished , loss_ave_val = 0.1919
# epoch-3 training finished , loss_ave_train = 0.1921
# epoch-3 testing finished , loss_ave_val = 0.1868
# epoch-4 training finished , loss_ave_train = 0.1870
# epoch-4 testing finished , loss_ave_val = 0.1841
# epoch-5 training finished , loss_ave_train = 0.1821
# epoch-5 testing finished , loss_ave_val = 0.1811
# epoch-6 training finished , loss_ave_train = 0.1784
# epoch-6 testing finished , loss_ave_val = 0.1790
# epoch-7 training finished , loss_ave_train = 0.1757
# epoch-7 testing finished , loss_ave_val = 0.1779
# epoch-8 training finished , loss_ave_train = 0.1735
# epoch-8 testing finished , loss_ave_val = 0.1772
# epoch-9 training finished , loss_ave_train = 0.1716
# epoch-9 testing finished , loss_ave_val = 0.1766
# epoch-10 training finished , loss_ave_train = 0.1700
# epoch-10 testing finished , loss_ave_val = 0.1762
# epoch-11 training finished , loss_ave_train = 0.1686
# epoch-11 testing finished , loss_ave_val = 0.1764
# epoch-12 training finished , loss_ave_train = 0.1674
# epoch-12 testing finished , loss_ave_val = 0.1764
# epoch-13 training finished , loss_ave_train = 0.1663
# epoch-13 testing finished , loss_ave_val = 0.1765
# epoch-14 training finished , loss_ave_train = 0.1654
# epoch-14 testing finished , loss_ave_val = 0.1765
# epoch-15 training finished , loss_ave_train = 0.1646
# epoch-15 testing finished , loss_ave_val = 0.1770
# epoch-16 training finished , loss_ave_train = 0.1638
# epoch-16 testing finished , loss_ave_val = 0.1773
# epoch-17 training finished , loss_ave_train = 0.1631
# epoch-17 testing finished , loss_ave_val = 0.1776
# epoch-18 training finished , loss_ave_train = 0.1625
# epoch-18 testing finished , loss_ave_val = 0.1779
# epoch-19 training finished , loss_ave_train = 0.1619
# epoch-19 testing finished , loss_ave_val = 0.1782
# epoch-20 training finished , loss_ave_train = 0.1613
# epoch-20 testing finished , loss_ave_val = 0.1782
# epoch-21 training finished , loss_ave_train = 0.1608
# epoch-21 testing finished , loss_ave_val = 0.1784
# epoch-22 training finished , loss_ave_train = 0.1603
# epoch-22 testing finished , loss_ave_val = 0.1787
# epoch-23 training finished , loss_ave_train = 0.1598
# epoch-23 testing finished , loss_ave_val = 0.1790
# epoch-24 training finished , loss_ave_train = 0.1594
# epoch-24 testing finished , loss_ave_val = 0.1808
# epoch-25 training finished , loss_ave_train = 0.1590
# epoch-25 testing finished , loss_ave_val = 0.1809
# epoch-26 training finished , loss_ave_train = 0.1586
# epoch-26 testing finished , loss_ave_val = 0.1810
# epoch-27 training finished , loss_ave_train = 0.1582
# epoch-27 testing finished , loss_ave_val = 0.1796
# epoch-28 training finished , loss_ave_train = 0.1578
# epoch-28 testing finished , loss_ave_val = 0.1813
# epoch-29 training finished , loss_ave_train = 0.1575
# epoch-29 testing finished , loss_ave_val = 0.1814
# epoch-30 training finished , loss_ave_train = 0.1572
# epoch-30 testing finished , loss_ave_val = 0.1817
# ***get the model NetMHCpan_10_fold1***
# epoch-1 training finished , loss_ave_train = 0.2545
# epoch-1 testing finished , loss_ave_val = 0.2113
# epoch-2 training finished , loss_ave_train = 0.2004
# epoch-2 testing finished , loss_ave_val = 0.2247
# epoch-3 training finished , loss_ave_train = 0.1870
# epoch-3 testing finished , loss_ave_val = 0.2153
# epoch-4 training finished , loss_ave_train = 0.1782
# epoch-4 testing finished , loss_ave_val = 0.2142
# epoch-5 training finished , loss_ave_train = 0.1714
# epoch-5 testing finished , loss_ave_val = 0.2222
# epoch-6 training finished , loss_ave_train = 0.1659
# epoch-6 testing finished , loss_ave_val = 0.2253
# epoch-7 training finished , loss_ave_train = 0.1629
# epoch-7 testing finished , loss_ave_val = 0.2269
# epoch-8 training finished , loss_ave_train = 0.1600
# epoch-8 testing finished , loss_ave_val = 0.2296
# epoch-9 training finished , loss_ave_train = 0.1576
# epoch-9 testing finished , loss_ave_val = 0.2354
# epoch-10 training finished , loss_ave_train = 0.1556
# epoch-10 testing finished , loss_ave_val = 0.2348
# epoch-11 training finished , loss_ave_train = 0.1531
# epoch-11 testing finished , loss_ave_val = 0.2324
# epoch-12 training finished , loss_ave_train = 0.1508
# epoch-12 testing finished , loss_ave_val = 0.2302
# epoch-13 training finished , loss_ave_train = 0.1491
# epoch-13 testing finished , loss_ave_val = 0.2271
# epoch-14 training finished , loss_ave_train = 0.1475
# epoch-14 testing finished , loss_ave_val = 0.2361
# epoch-15 training finished , loss_ave_train = 0.1460
# epoch-15 testing finished , loss_ave_val = 0.2306
# epoch-16 training finished , loss_ave_train = 0.1443
# epoch-16 testing finished , loss_ave_val = 0.2321
# epoch-17 training finished , loss_ave_train = 0.1433
# epoch-17 testing finished , loss_ave_val = 0.2370
# epoch-18 training finished , loss_ave_train = 0.1421
# epoch-18 testing finished , loss_ave_val = 0.2357
# epoch-19 training finished , loss_ave_train = 0.1410
# epoch-19 testing finished , loss_ave_val = 0.2347
# epoch-20 training finished , loss_ave_train = 0.1400
# epoch-20 testing finished , loss_ave_val = 0.2352
# epoch-21 training finished , loss_ave_train = 0.1387
# epoch-21 testing finished , loss_ave_val = 0.2393
# epoch-22 training finished , loss_ave_train = 0.1381
# epoch-22 testing finished , loss_ave_val = 0.2380
# epoch-23 training finished , loss_ave_train = 0.1375
# epoch-23 testing finished , loss_ave_val = 0.2369
# epoch-24 training finished , loss_ave_train = 0.1367
# epoch-24 testing finished , loss_ave_val = 0.2340
# epoch-25 training finished , loss_ave_train = 0.1363
# epoch-25 testing finished , loss_ave_val = 0.2319
# epoch-26 training finished , loss_ave_train = 0.1349
# epoch-26 testing finished , loss_ave_val = 0.2350
# epoch-27 training finished , loss_ave_train = 0.1340
# epoch-27 testing finished , loss_ave_val = 0.2332
# epoch-28 training finished , loss_ave_train = 0.1337
# epoch-28 testing finished , loss_ave_val = 0.2304
# epoch-29 training finished , loss_ave_train = 0.1325
# epoch-29 testing finished , loss_ave_val = 0.2304
# epoch-30 training finished , loss_ave_train = 0.1317
# epoch-30 testing finished , loss_ave_val = 0.2301
# ***get the model NetMHCpan_10_fold2***
# epoch-1 training finished , loss_ave_train = 0.2603
# epoch-1 testing finished , loss_ave_val = 0.2086
# epoch-2 training finished , loss_ave_train = 0.2040
# epoch-2 testing finished , loss_ave_val = 0.2071
# epoch-3 training finished , loss_ave_train = 0.1927
# epoch-3 testing finished , loss_ave_val = 0.2110
# epoch-4 training finished , loss_ave_train = 0.1849
# epoch-4 testing finished , loss_ave_val = 0.2120
# epoch-5 training finished , loss_ave_train = 0.1795
# epoch-5 testing finished , loss_ave_val = 0.2130
# epoch-6 training finished , loss_ave_train = 0.1754
# epoch-6 testing finished , loss_ave_val = 0.2137
# epoch-7 training finished , loss_ave_train = 0.1724
# epoch-7 testing finished , loss_ave_val = 0.2145
# epoch-8 training finished , loss_ave_train = 0.1702
# epoch-8 testing finished , loss_ave_val = 0.2148
# epoch-9 training finished , loss_ave_train = 0.1683
# epoch-9 testing finished , loss_ave_val = 0.2141
# epoch-10 training finished , loss_ave_train = 0.1667
# epoch-10 testing finished , loss_ave_val = 0.2144
# epoch-11 training finished , loss_ave_train = 0.1652
# epoch-11 testing finished , loss_ave_val = 0.2168
# epoch-12 training finished , loss_ave_train = 0.1640
# epoch-12 testing finished , loss_ave_val = 0.2166
# epoch-13 training finished , loss_ave_train = 0.1629
# epoch-13 testing finished , loss_ave_val = 0.2165
# epoch-14 training finished , loss_ave_train = 0.1619
# epoch-14 testing finished , loss_ave_val = 0.2167
# epoch-15 training finished , loss_ave_train = 0.1610
# epoch-15 testing finished , loss_ave_val = 0.2170
# epoch-16 training finished , loss_ave_train = 0.1602
# epoch-16 testing finished , loss_ave_val = 0.2170
# epoch-17 training finished , loss_ave_train = 0.1594
# epoch-17 testing finished , loss_ave_val = 0.2172
# epoch-18 training finished , loss_ave_train = 0.1587
# epoch-18 testing finished , loss_ave_val = 0.2179
# epoch-19 training finished , loss_ave_train = 0.1580
# epoch-19 testing finished , loss_ave_val = 0.2183
# epoch-20 training finished , loss_ave_train = 0.1573
# epoch-20 testing finished , loss_ave_val = 0.2186
# epoch-21 training finished , loss_ave_train = 0.1568
# epoch-21 testing finished , loss_ave_val = 0.2188
# epoch-22 training finished , loss_ave_train = 0.1562
# epoch-22 testing finished , loss_ave_val = 0.2191
# epoch-23 training finished , loss_ave_train = 0.1557
# epoch-23 testing finished , loss_ave_val = 0.2193
# epoch-24 training finished , loss_ave_train = 0.1552
# epoch-24 testing finished , loss_ave_val = 0.2195
# epoch-25 training finished , loss_ave_train = 0.1548
# epoch-25 testing finished , loss_ave_val = 0.2199
# epoch-26 training finished , loss_ave_train = 0.1544
# epoch-26 testing finished , loss_ave_val = 0.2202
# epoch-27 training finished , loss_ave_train = 0.1540
# epoch-27 testing finished , loss_ave_val = 0.2206
# epoch-28 training finished , loss_ave_train = 0.1536
# epoch-28 testing finished , loss_ave_val = 0.2209
# epoch-29 training finished , loss_ave_train = 0.1533
# epoch-29 testing finished , loss_ave_val = 0.2204
# epoch-30 training finished , loss_ave_train = 0.1529
# epoch-30 testing finished , loss_ave_val = 0.2206
# ***get the model NetMHCpan_10_fold3***
# epoch-1 training finished , loss_ave_train = 0.3040
# epoch-1 testing finished , loss_ave_val = 0.2040
# epoch-2 training finished , loss_ave_train = 0.2073
# epoch-2 testing finished , loss_ave_val = 0.1953
# epoch-3 training finished , loss_ave_train = 0.1951
# epoch-3 testing finished , loss_ave_val = 0.1910
# epoch-4 training finished , loss_ave_train = 0.1865
# epoch-4 testing finished , loss_ave_val = 0.1888
# epoch-5 training finished , loss_ave_train = 0.1799
# epoch-5 testing finished , loss_ave_val = 0.1882
# epoch-6 training finished , loss_ave_train = 0.1758
# epoch-6 testing finished , loss_ave_val = 0.1878
# epoch-7 training finished , loss_ave_train = 0.1728
# epoch-7 testing finished , loss_ave_val = 0.1871
# epoch-8 training finished , loss_ave_train = 0.1703
# epoch-8 testing finished , loss_ave_val = 0.1867
# epoch-9 training finished , loss_ave_train = 0.1683
# epoch-9 testing finished , loss_ave_val = 0.1863
# epoch-10 training finished , loss_ave_train = 0.1666
# epoch-10 testing finished , loss_ave_val = 0.1860
# epoch-11 training finished , loss_ave_train = 0.1651
# epoch-11 testing finished , loss_ave_val = 0.1856
# epoch-12 training finished , loss_ave_train = 0.1639
# epoch-12 testing finished , loss_ave_val = 0.1854
# epoch-13 training finished , loss_ave_train = 0.1627
# epoch-13 testing finished , loss_ave_val = 0.1853
# epoch-14 training finished , loss_ave_train = 0.1617
# epoch-14 testing finished , loss_ave_val = 0.1852
# epoch-15 training finished , loss_ave_train = 0.1608
# epoch-15 testing finished , loss_ave_val = 0.1851
# epoch-16 training finished , loss_ave_train = 0.1599
# epoch-16 testing finished , loss_ave_val = 0.1851
# epoch-17 training finished , loss_ave_train = 0.1592
# epoch-17 testing finished , loss_ave_val = 0.1850
# epoch-18 training finished , loss_ave_train = 0.1585
# epoch-18 testing finished , loss_ave_val = 0.1849
# epoch-19 training finished , loss_ave_train = 0.1578
# epoch-19 testing finished , loss_ave_val = 0.1848
# epoch-20 training finished , loss_ave_train = 0.1572
# epoch-20 testing finished , loss_ave_val = 0.1844
# epoch-21 training finished , loss_ave_train = 0.1566
# epoch-21 testing finished , loss_ave_val = 0.1843
# epoch-22 training finished , loss_ave_train = 0.1561
# epoch-22 testing finished , loss_ave_val = 0.1842
# epoch-23 training finished , loss_ave_train = 0.1556
# epoch-23 testing finished , loss_ave_val = 0.1843
# epoch-24 training finished , loss_ave_train = 0.1550
# epoch-24 testing finished , loss_ave_val = 0.1842
# epoch-25 training finished , loss_ave_train = 0.1543
# epoch-25 testing finished , loss_ave_val = 0.1847
# epoch-26 training finished , loss_ave_train = 0.1539
# epoch-26 testing finished , loss_ave_val = 0.1848
# epoch-27 training finished , loss_ave_train = 0.1535
# epoch-27 testing finished , loss_ave_val = 0.1848
# epoch-28 training finished , loss_ave_train = 0.1531
# epoch-28 testing finished , loss_ave_val = 0.1848
# epoch-29 training finished , loss_ave_train = 0.1527
# epoch-29 testing finished , loss_ave_val = 0.1848
# epoch-30 training finished , loss_ave_train = 0.1523
# epoch-30 testing finished , loss_ave_val = 0.1848
# ***get the model NetMHCpan_10_fold4***

# %%
#平均评估loss
epoch = [e+1 for e in range(epoch_num)]
loss_val_ave = []
for e in range(epoch_num):
    sum = 0
    for n in range(fold):
        sum += loss_val_sum[n*epoch_num + e]
    loss_val_ave.append(sum/fold)
plt.figure(fold+1)
plt.plot(epoch, loss_val_ave, marker='o', markersize=3)
plt.xlabel('epoch'),plt.ylabel('loss')
plt.title("model's validation result")
# Out:
# Text(0.5, 1.0, "model's validation result")

# %% [markdown]
# ##### 在其他data_set上的accuracy

# %%
#independent_set
import pandas as pd
import numpy as np
import torch

'''BLOSUM50'''
BLOSUM50_Matrix = pd.read_table('BLOSUM50_Matrix.txt',sep = '\s+')          #用\s+,如果用\t会让txt中第一列会被当作数据
amino_acid_sort = ['A','R','N','D','C','Q','E','G','H','I','L','K','M','F','P','S','T','W','Y','V','B','J','Z','X']    #X可以用于padding
amino_acid_num = len(amino_acid_sort)
BLOSUM50_Matrix = BLOSUM50_Matrix.loc[amino_acid_sort, amino_acid_sort]     #去掉BLOSUM50中的*

#参数
pep_len_max = 14
HLA_len = 34

input_size = (pep_len_max + HLA_len) * amino_acid_num   #pHLA编码长度
hidden_size = 60                                        #22-86 from paper
output_size = 1                                         #a single neroun

fold = 5

#设备
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')       #有GPU就用GPU

'''提取数据'''
pep_data = pd.read_csv("data_csv/independent_set2.csv",usecols=["peptide","length"]) 
HLA_data = pd.read_csv("data_csv/independent_set2.csv",usecols=["HLA_sequence"]) 
bind_data = pd.read_csv("data_csv/independent_set2.csv",usecols=["label"]) 

pep_seq, pep_len, pep_len_max= np.array(pep_data["peptide"]), np.array(pep_data["length"]), 14
HLA_seq, HLA_len = np.array(HLA_data["HLA_sequence"]), 34
bind_label = np.array(bind_data["label"])

data_num = bind_label.size          #数据数量

'''加载模型'''
use_model = torch.load("model/NetMHCpan_10_fold2.pkl")

'''预测'''
pre_result = np.zeros(data_num)

for i in range(data_num):

    '''编码'''
    pHLA_code = np.zeros((HLA_len+pep_len_max, amino_acid_num))

    for j in range(pep_len[i]):
        pHLA_code[j,:] = BLOSUM50_Matrix[pep_seq[i][j]]             #先对peptide编码

    for j in range(pep_len[i], pep_len_max):
        pHLA_code[j,:] = BLOSUM50_Matrix['X']                       #peptide长度不足14，padding，用X编码 

    for j in range(HLA_len):
        pHLA_code[j+pep_len_max,:] = BLOSUM50_Matrix[HLA_seq[i][j]] #最后对HLA序列编码，放在后面

    pHLA_code = pHLA_code.reshape(-1, input_size)                   #转为1*1152数组

    '''前向传播，得到预测'''
    pHLA_code = torch.Tensor(pHLA_code).to(device)                  #输入GPU
    target = bind_label[i]
    target = target.reshape(-1,1)
    target = torch.Tensor(target).to(device, dtype = torch.float)   #MSE backward()中要求是float，不是long

    prediction = use_model(pHLA_code)
    pre_result[i] = prediction.item()

'''probability--->binding(1) or non-binding(0)'''
pre_result[pre_result >= 0.5] = 1
pre_result[pre_result < 0.5] = 0

'''prediction与label比较'''
pre_result[pre_result != bind_label] = 0    #用pre_result保存比较结果
pre_result[pre_result == bind_label] = 1

correct_num = np.sum(pre_result)
accuracy = correct_num/data_num
print("accuracy on independent_set is {:.4f}".format(accuracy))
# Out:
# accuracy on independent_set is 0.9156

# %%
#external_set
'''BLOSUM50'''
BLOSUM50_Matrix = pd.read_table('BLOSUM50_Matrix.txt',sep = '\s+')          #用\s+,如果用\t会让txt中第一列会被当作数据
amino_acid_sort = ['A','R','N','D','C','Q','E','G','H','I','L','K','M','F','P','S','T','W','Y','V','B','J','Z','X']    #X可以用于padding
amino_acid_num = len(amino_acid_sort)
BLOSUM50_Matrix = BLOSUM50_Matrix.loc[amino_acid_sort, amino_acid_sort]     #去掉BLOSUM50中的*

'''提取数据'''
pep_data = pd.read_csv("data_csv/external_set2.csv",usecols=["peptide","length"]) 
HLA_data = pd.read_csv("data_csv/external_set2.csv",usecols=["HLA_sequence"]) 
bind_data = pd.read_csv("data_csv/external_set2.csv",usecols=["label"]) 

pep_seq, pep_len, pep_len_max= np.array(pep_data["peptide"]), np.array(pep_data["length"]), 14
HLA_seq, HLA_len = np.array(HLA_data["HLA_sequence"]), 34
bind_label = np.array(bind_data["label"])

data_num = bind_label.size          #数据数量

'''加载模型'''
use_model = torch.load("model/NetMHCpan_10_fold2.pkl")

'''预测'''
pre_result = np.zeros(data_num)

for i in range(data_num):

    '''编码'''
    pHLA_code = np.zeros((HLA_len+pep_len_max, amino_acid_num))

    for j in range(pep_len[i]):
        pHLA_code[j,:] = BLOSUM50_Matrix[pep_seq[i][j]]             #先对peptide编码

    for j in range(pep_len[i], pep_len_max):
        pHLA_code[j,:] = BLOSUM50_Matrix['X']                       #peptide长度不足14，padding，用X编码 

    for j in range(HLA_len):
        pHLA_code[j+pep_len_max,:] = BLOSUM50_Matrix[HLA_seq[i][j]] #最后对HLA序列编码，放在后面

    pHLA_code = pHLA_code.reshape(-1, input_size)                   #转为1*1152数组

    '''前向传播，得到预测'''
    pHLA_code = torch.Tensor(pHLA_code).to(device)                  #输入GPU
    target = bind_label[i]
    target = target.reshape(-1,1)
    target = torch.Tensor(target).to(device, dtype = torch.float)   #MSE backward()中要求是float，不是long

    prediction = use_model(pHLA_code)
    pre_result[i] = prediction.item()

'''probability--->binding(1) or non-binding(0)'''
pre_result[pre_result >= 0.5] = 1
pre_result[pre_result < 0.5] = 0

'''prediction与label比较'''
pre_result[pre_result != bind_label] = 0    #用pre_result保存比较结果
pre_result[pre_result == bind_label] = 1

correct_num = np.sum(pre_result)
accuracy = correct_num/data_num
print("accuracy on external_set is {}".format(accuracy))
# Out:
# accuracy on external_set is 0.954

# %% [markdown]
# fold1
