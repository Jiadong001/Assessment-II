# %% [markdown]
# ### Model 2 --- NetMHCpan1.0_LSTM

# %% [markdown]
# ##### 训练模型

# %%
import pandas as pd
import numpy as np

import torch
import task_models
import torch.nn as nn
import torch.optim as optim

import matplotlib.pyplot as plt

'''BLOSUM50'''
BLOSUM50_Matrix = pd.read_table('BLOSUM50_Matrix.txt',sep = '\s+')          #用\s+,如果用\t会让txt中第一列会被当作数据
amino_acid_sort = ['A','R','N','D','C','Q','E','G','H','I','L','K','M','F','P','S','T','W','Y','V','B','J','Z','X']    #X可以用于padding
amino_acid_num = len(amino_acid_sort)
BLOSUM50_Matrix = BLOSUM50_Matrix.loc[amino_acid_sort, amino_acid_sort]     #去掉BLOSUM50中的*

'''训练'''
#参数
pep_len_max = 14
HLA_len = 34

embedding_dim = amino_acid_num
lstm_hidden_size = 16                                   #16 from paper
hidden_size = 60                                        #60 from paper
output_size = 1                                         #a single neroun

epoch_num = 30
learning_rate = 0.0005

fold = 5

#设备
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')       #有GPU就用GPU

loss_val_sum = []           #保存每个epoch中，5个模型平均评估loss之和，用于计算最后的平均结果

#开始 5fold-cv 训练
for f in range(fold):

    #模型
    model = task_models.NetMHCpan_10_LSTM(embedding_dim, embedding_dim, lstm_hidden_size, hidden_size, output_size).to(device)

    #优化方式
    loss_fn = nn.MSELoss()                                               #MSE-loss
    optimizer = optim.Adam(model.parameters(), lr = learning_rate)       #Adam优化方式

    train_data_num = [n for n in range(fold)]   #训练数据编号
    train_data_num.pop(f)                       #拿出一组训练数据用于评估，其余用于训练

    loss_ave_train = []         #保存每个epoch的平均训练loss
    loss_ave_val = []           #保存每个epoch的平均评估loss

    #训练30个epoch
    for e in range(epoch_num):

        #训练模型
        loss_all_train = []       #保存1个epoch中每个数据的loss

        #用训练数据训练
        for ff in train_data_num:
            '''提取数据'''
            pep_data = pd.read_csv("data_csv/train_data_fold{}.csv".format(ff),usecols=["peptide","length"]) 
            HLA_data = pd.read_csv("data_csv/train_data_fold{}.csv".format(ff),usecols=["HLA_sequence"]) 
            bind_data = pd.read_csv("data_csv/train_data_fold{}.csv".format(ff),usecols=["label"]) 

            pep_seq, pep_len = np.array(pep_data["peptide"]), np.array(pep_data["length"])
            HLA_seq = np.array(HLA_data["HLA_sequence"])
            bind_label = np.array(bind_data["label"])

            data_num = bind_label.size          #数据数量

            for i in range(data_num):

                '''先编码'''
                pep_code = np.zeros((pep_len_max, amino_acid_num))
                HLA_code = np.zeros((HLA_len, amino_acid_num))

                for j in range(pep_len[i]):
                    pep_code[j,:] = BLOSUM50_Matrix[pep_seq[i][j]]              #先对peptide编码

                for j in range(pep_len[i], pep_len_max):
                    pep_code[j,:] = BLOSUM50_Matrix['X']                        #peptide长度不足14，padding，用X编码 

                for j in range(HLA_len):
                    HLA_code[j,:] = BLOSUM50_Matrix[HLA_seq[i][j]]              #对HLA序列编码
                
                pep_code = pep_code.reshape(-1, 1, embedding_dim)               #lstm input: shape = [seq_length, batch_size, input_size]的张量
                HLA_code = HLA_code.reshape(-1, 1, embedding_dim)               #batch_size = 1

                '''前向传播，得到预测与误差'''
                pep_code = torch.Tensor(pep_code).to(device)                    #输入GPU
                HLA_code = torch.Tensor(HLA_code).to(device)

                target = bind_label[i]
                target = target.reshape(-1,1)
                target = torch.Tensor(target).to(device, dtype = torch.float)   #MSE backward()中要求是float，不是long

                prediction = model(pep_code, HLA_code)                         
                loss = loss_fn(prediction, target)
                loss_all_train.append(loss.item())

                '''后向传播，更新模型参数'''
                optimizer.zero_grad()   #梯度清零
                loss.backward()         #计算梯度
                optimizer.step()        #更新参数

        loss_ave_train.append(np.mean(loss_all_train))
        print('epoch-{} training finished , loss_ave_train = {:.4f}'.format(e+1, np.mean(loss_all_train)))


        #用剩余的一组数据评估模型
        loss_all_val = []       #保存1个epoch中每个数据的loss

        '''提取数据'''
        pep_data = pd.read_csv("data_csv/train_data_fold{}.csv".format(f),usecols=["peptide","length"]) 
        HLA_data = pd.read_csv("data_csv/train_data_fold{}.csv".format(f),usecols=["HLA_sequence"]) 
        bind_data = pd.read_csv("data_csv/train_data_fold{}.csv".format(f),usecols=["label"]) 

        pep_seq, pep_len, pep_len_max= np.array(pep_data["peptide"]), np.array(pep_data["length"]), 14
        HLA_seq, HLA_len = np.array(HLA_data["HLA_sequence"]), 34
        bind_label = np.array(bind_data["label"])

        data_num = bind_label.size          #数据数量

        for i in range(data_num):

            '''先编码'''
            pep_code = np.zeros((pep_len_max, amino_acid_num))
            HLA_code = np.zeros((HLA_len, amino_acid_num))

            for j in range(pep_len[i]):
                pep_code[j,:] = BLOSUM50_Matrix[pep_seq[i][j]]              #先对peptide编码

            for j in range(pep_len[i], pep_len_max):
                pep_code[j,:] = BLOSUM50_Matrix['X']                        #peptide长度不足14，padding，用X编码 

            for j in range(HLA_len):
                HLA_code[j,:] = BLOSUM50_Matrix[HLA_seq[i][j]]              #对HLA序列编码
            
            pep_code = pep_code.reshape(-1, 1, embedding_dim)               #lstm input: shape = [seq_length, batch_size, input_size]的张量
            HLA_code = HLA_code.reshape(-1, 1, embedding_dim)               #batch_size = 1           

            '''前向传播，得到预测与误差'''
            pep_code = torch.Tensor(pep_code).to(device)                    #输入GPU
            HLA_code = torch.Tensor(HLA_code).to(device)

            target = bind_label[i]
            target = target.reshape(-1,1)
            target = torch.Tensor(target).to(device, dtype = torch.float)   #MSE backward()中要求是float，不是long

            prediction = model.forward(pep_code, HLA_code)
            loss = loss_fn(prediction, target)
            loss_all_val.append(loss.item())

        loss_ave_val.append(np.mean(loss_all_val))
        print('epoch-{} testing finished , loss_ave_val = {:.4f}'.format(e+1, np.mean(loss_all_val)))
    
    loss_val_sum += loss_ave_val

    #作图，画出loss-epoch折线
    epoch = [e+1 for e in range(epoch_num)]

    plt.figure(f+1)
    plt.plot(epoch, loss_ave_train, marker='o', markersize=2)
    plt.plot(epoch, loss_ave_val, marker='o', markersize=2)
    plt.ylim(0.05, 0.35)
    plt.legend(['train','val'])
    plt.xlabel('epoch'),plt.ylabel('loss_ave')
    plt.title("fold{} as val_data".format(f))

    #保存当前模型
    torch.save(model, "model/NetMHCpan_10_LSTM_fold{}.pkl".format(f))
    print("***get the model NetMHCpan_10_LSTM_fold{}***".format(f))
# Out:
# epoch-1 training finished , loss_ave_train = 0.2162
# epoch-1 testing finished , loss_ave_val = 0.1914
# epoch-2 training finished , loss_ave_train = 0.1841
# epoch-2 testing finished , loss_ave_val = 0.1858
# epoch-3 training finished , loss_ave_train = 0.1746
# epoch-3 testing finished , loss_ave_val = 0.1849
# epoch-4 training finished , loss_ave_train = 0.1690
# epoch-4 testing finished , loss_ave_val = 0.1871
# epoch-5 training finished , loss_ave_train = 0.1651
# epoch-5 testing finished , loss_ave_val = 0.1893
# epoch-6 training finished , loss_ave_train = 0.1623
# epoch-6 testing finished , loss_ave_val = 0.1912
# epoch-7 training finished , loss_ave_train = 0.1606
# epoch-7 testing finished , loss_ave_val = 0.1890
# epoch-8 training finished , loss_ave_train = 0.1586
# epoch-8 testing finished , loss_ave_val = 0.1856
# epoch-9 training finished , loss_ave_train = 0.1571
# epoch-9 testing finished , loss_ave_val = 0.1858
# epoch-10 training finished , loss_ave_train = 0.1544
# epoch-10 testing finished , loss_ave_val = 0.1844
# epoch-11 training finished , loss_ave_train = 0.1520
# epoch-11 testing finished , loss_ave_val = 0.1804
# epoch-12 training finished , loss_ave_train = 0.1513
# epoch-12 testing finished , loss_ave_val = 0.1790
# epoch-13 training finished , loss_ave_train = 0.1476
# epoch-13 testing finished , loss_ave_val = 0.1790
# epoch-14 training finished , loss_ave_train = 0.1462
# epoch-14 testing finished , loss_ave_val = 0.1770
# epoch-15 training finished , loss_ave_train = 0.1445
# epoch-15 testing finished , loss_ave_val = 0.1740
# epoch-16 training finished , loss_ave_train = 0.1431
# epoch-16 testing finished , loss_ave_val = 0.1744
# epoch-17 training finished , loss_ave_train = 0.1408
# epoch-17 testing finished , loss_ave_val = 0.1722
# epoch-18 training finished , loss_ave_train = 0.1390
# epoch-18 testing finished , loss_ave_val = 0.1740
# epoch-19 training finished , loss_ave_train = 0.1373
# epoch-19 testing finished , loss_ave_val = 0.1731
# epoch-20 training finished , loss_ave_train = 0.1368
# epoch-20 testing finished , loss_ave_val = 0.1724
# epoch-21 training finished , loss_ave_train = 0.1337
# epoch-21 testing finished , loss_ave_val = 0.1687
# epoch-22 training finished , loss_ave_train = 0.1343
# epoch-22 testing finished , loss_ave_val = 0.1684
# epoch-23 training finished , loss_ave_train = 0.1311
# epoch-23 testing finished , loss_ave_val = 0.1748
# epoch-24 training finished , loss_ave_train = 0.1281
# epoch-24 testing finished , loss_ave_val = 0.1666
# epoch-25 training finished , loss_ave_train = 0.1251
# epoch-25 testing finished , loss_ave_val = 0.1707
# epoch-26 training finished , loss_ave_train = 0.1223
# epoch-26 testing finished , loss_ave_val = 0.1764
# epoch-27 training finished , loss_ave_train = 0.1226
# epoch-27 testing finished , loss_ave_val = 0.1759
# epoch-28 training finished , loss_ave_train = 0.1204
# epoch-28 testing finished , loss_ave_val = 0.1645
# epoch-29 training finished , loss_ave_train = 0.1175
# epoch-29 testing finished , loss_ave_val = 0.1669
# epoch-30 training finished , loss_ave_train = 0.1143
# epoch-30 testing finished , loss_ave_val = 0.1729
# ***get the model NetMHCpan_10_LSTM_fold0***
# epoch-1 training finished , loss_ave_train = 0.2157
# epoch-1 testing finished , loss_ave_val = 0.1844
# epoch-2 training finished , loss_ave_train = 0.1805
# epoch-2 testing finished , loss_ave_val = 0.1702
# epoch-3 training finished , loss_ave_train = 0.1703
# epoch-3 testing finished , loss_ave_val = 0.1640
# epoch-4 training finished , loss_ave_train = 0.1633
# epoch-4 testing finished , loss_ave_val = 0.1639
# epoch-5 training finished , loss_ave_train = 0.1595
# epoch-5 testing finished , loss_ave_val = 0.1636
# epoch-6 training finished , loss_ave_train = 0.1563
# epoch-6 testing finished , loss_ave_val = 0.1630
# epoch-7 training finished , loss_ave_train = 0.1538
# epoch-7 testing finished , loss_ave_val = 0.1640
# epoch-8 training finished , loss_ave_train = 0.1515
# epoch-8 testing finished , loss_ave_val = 0.1640
# epoch-9 training finished , loss_ave_train = 0.1489
# epoch-9 testing finished , loss_ave_val = 0.1640
# epoch-10 training finished , loss_ave_train = 0.1467
# epoch-10 testing finished , loss_ave_val = 0.1652
# epoch-11 training finished , loss_ave_train = 0.1441
# epoch-11 testing finished , loss_ave_val = 0.1656
# epoch-12 training finished , loss_ave_train = 0.1415
# epoch-12 testing finished , loss_ave_val = 0.1680
# epoch-13 training finished , loss_ave_train = 0.1395
# epoch-13 testing finished , loss_ave_val = 0.1673
# epoch-14 training finished , loss_ave_train = 0.1368
# epoch-14 testing finished , loss_ave_val = 0.1679
# epoch-15 training finished , loss_ave_train = 0.1354
# epoch-15 testing finished , loss_ave_val = 0.1680
# epoch-16 training finished , loss_ave_train = 0.1315
# epoch-16 testing finished , loss_ave_val = 0.1690
# epoch-17 training finished , loss_ave_train = 0.1282
# epoch-17 testing finished , loss_ave_val = 0.1710
# epoch-18 training finished , loss_ave_train = 0.1252
# epoch-18 testing finished , loss_ave_val = 0.1741
# epoch-19 training finished , loss_ave_train = 0.1233
# epoch-19 testing finished , loss_ave_val = 0.1714
# epoch-20 training finished , loss_ave_train = 0.1193
# epoch-20 testing finished , loss_ave_val = 0.1723
# epoch-21 training finished , loss_ave_train = 0.1184
# epoch-21 testing finished , loss_ave_val = 0.1801
# epoch-22 training finished , loss_ave_train = 0.1163
# epoch-22 testing finished , loss_ave_val = 0.1780
# epoch-23 training finished , loss_ave_train = 0.1141
# epoch-23 testing finished , loss_ave_val = 0.1693
# epoch-24 training finished , loss_ave_train = 0.1128
# epoch-24 testing finished , loss_ave_val = 0.1665
# epoch-25 training finished , loss_ave_train = 0.1076
# epoch-25 testing finished , loss_ave_val = 0.1719
# epoch-26 training finished , loss_ave_train = 0.1072
# epoch-26 testing finished , loss_ave_val = 0.1688
# epoch-27 training finished , loss_ave_train = 0.1025
# epoch-27 testing finished , loss_ave_val = 0.1673
# epoch-28 training finished , loss_ave_train = 0.0993
# epoch-28 testing finished , loss_ave_val = 0.1630
# epoch-29 training finished , loss_ave_train = 0.1006
# epoch-29 testing finished , loss_ave_val = 0.1698
# epoch-30 training finished , loss_ave_train = 0.0974
# epoch-30 testing finished , loss_ave_val = 0.1694
# ***get the model NetMHCpan_10_LSTM_fold1***
# epoch-1 training finished , loss_ave_train = 0.2218
# epoch-1 testing finished , loss_ave_val = 0.2103
# epoch-2 training finished , loss_ave_train = 0.1811
# epoch-2 testing finished , loss_ave_val = 0.1902
# epoch-3 training finished , loss_ave_train = 0.1699
# epoch-3 testing finished , loss_ave_val = 0.1908
# epoch-4 training finished , loss_ave_train = 0.1648
# epoch-4 testing finished , loss_ave_val = 0.1885
# epoch-5 training finished , loss_ave_train = 0.1609
# epoch-5 testing finished , loss_ave_val = 0.1869
# epoch-6 training finished , loss_ave_train = 0.1570
# epoch-6 testing finished , loss_ave_val = 0.1860
# epoch-7 training finished , loss_ave_train = 0.1539
# epoch-7 testing finished , loss_ave_val = 0.1874
# epoch-8 training finished , loss_ave_train = 0.1512
# epoch-8 testing finished , loss_ave_val = 0.1875
# epoch-9 training finished , loss_ave_train = 0.1487
# epoch-9 testing finished , loss_ave_val = 0.1890
# epoch-10 training finished , loss_ave_train = 0.1458
# epoch-10 testing finished , loss_ave_val = 0.1882
# epoch-11 training finished , loss_ave_train = 0.1432
# epoch-11 testing finished , loss_ave_val = 0.1886
# epoch-12 training finished , loss_ave_train = 0.1409
# epoch-12 testing finished , loss_ave_val = 0.1887
# epoch-13 training finished , loss_ave_train = 0.1402
# epoch-13 testing finished , loss_ave_val = 0.1846
# epoch-14 training finished , loss_ave_train = 0.1394
# epoch-14 testing finished , loss_ave_val = 0.1826
# epoch-15 training finished , loss_ave_train = 0.1362
# epoch-15 testing finished , loss_ave_val = 0.1864
# epoch-16 training finished , loss_ave_train = 0.1320
# epoch-16 testing finished , loss_ave_val = 0.1827
# epoch-17 training finished , loss_ave_train = 0.1317
# epoch-17 testing finished , loss_ave_val = 0.1868
# epoch-18 training finished , loss_ave_train = 0.1309
# epoch-18 testing finished , loss_ave_val = 0.1819
# epoch-19 training finished , loss_ave_train = 0.1265
# epoch-19 testing finished , loss_ave_val = 0.1798
# epoch-20 training finished , loss_ave_train = 0.1252
# epoch-20 testing finished , loss_ave_val = 0.1820
# epoch-21 training finished , loss_ave_train = 0.1233
# epoch-21 testing finished , loss_ave_val = 0.1762
# epoch-22 training finished , loss_ave_train = 0.1195
# epoch-22 testing finished , loss_ave_val = 0.1819
# epoch-23 training finished , loss_ave_train = 0.1173
# epoch-23 testing finished , loss_ave_val = 0.1859
# epoch-24 training finished , loss_ave_train = 0.1160
# epoch-24 testing finished , loss_ave_val = 0.1841
# epoch-25 training finished , loss_ave_train = 0.1136
# epoch-25 testing finished , loss_ave_val = 0.1851
# epoch-26 training finished , loss_ave_train = 0.1117
# epoch-26 testing finished , loss_ave_val = 0.1901
# epoch-27 training finished , loss_ave_train = 0.1120
# epoch-27 testing finished , loss_ave_val = 0.1827
# epoch-28 training finished , loss_ave_train = 0.1082
# epoch-28 testing finished , loss_ave_val = 0.1823
# epoch-29 training finished , loss_ave_train = 0.1045
# epoch-29 testing finished , loss_ave_val = 0.1773
# epoch-30 training finished , loss_ave_train = 0.1086
# epoch-30 testing finished , loss_ave_val = 0.1803
# ***get the model NetMHCpan_10_LSTM_fold2***
# epoch-1 training finished , loss_ave_train = 0.2193
# epoch-1 testing finished , loss_ave_val = 0.1906
# epoch-2 training finished , loss_ave_train = 0.1867
# epoch-2 testing finished , loss_ave_val = 0.1795
# epoch-3 training finished , loss_ave_train = 0.1774
# epoch-3 testing finished , loss_ave_val = 0.1778
# epoch-4 training finished , loss_ave_train = 0.1723
# epoch-4 testing finished , loss_ave_val = 0.1797
# epoch-5 training finished , loss_ave_train = 0.1687
# epoch-5 testing finished , loss_ave_val = 0.1648
# epoch-6 training finished , loss_ave_train = 0.1648
# epoch-6 testing finished , loss_ave_val = 0.1639
# epoch-7 training finished , loss_ave_train = 0.1614
# epoch-7 testing finished , loss_ave_val = 0.1637
# epoch-8 training finished , loss_ave_train = 0.1573
# epoch-8 testing finished , loss_ave_val = 0.1633
# epoch-9 training finished , loss_ave_train = 0.1537
# epoch-9 testing finished , loss_ave_val = 0.1627
# epoch-10 training finished , loss_ave_train = 0.1497
# epoch-10 testing finished , loss_ave_val = 0.1583
# epoch-11 training finished , loss_ave_train = 0.1472
# epoch-11 testing finished , loss_ave_val = 0.1560
# epoch-12 training finished , loss_ave_train = 0.1446
# epoch-12 testing finished , loss_ave_val = 0.1547
# epoch-13 training finished , loss_ave_train = 0.1433
# epoch-13 testing finished , loss_ave_val = 0.1529
# epoch-14 training finished , loss_ave_train = 0.1403
# epoch-14 testing finished , loss_ave_val = 0.1521
# epoch-15 training finished , loss_ave_train = 0.1383
# epoch-15 testing finished , loss_ave_val = 0.1508
# epoch-16 training finished , loss_ave_train = 0.1364
# epoch-16 testing finished , loss_ave_val = 0.1524
# epoch-17 training finished , loss_ave_train = 0.1355
# epoch-17 testing finished , loss_ave_val = 0.1534
# epoch-18 training finished , loss_ave_train = 0.1339
# epoch-18 testing finished , loss_ave_val = 0.1553
# epoch-19 training finished , loss_ave_train = 0.1330
# epoch-19 testing finished , loss_ave_val = 0.1574
# epoch-20 training finished , loss_ave_train = 0.1298
# epoch-20 testing finished , loss_ave_val = 0.1573
# epoch-21 training finished , loss_ave_train = 0.1283
# epoch-21 testing finished , loss_ave_val = 0.1585
# epoch-22 training finished , loss_ave_train = 0.1262
# epoch-22 testing finished , loss_ave_val = 0.1596
# epoch-23 training finished , loss_ave_train = 0.1235
# epoch-23 testing finished , loss_ave_val = 0.1620
# epoch-24 training finished , loss_ave_train = 0.1234
# epoch-24 testing finished , loss_ave_val = 0.1645
# epoch-25 training finished , loss_ave_train = 0.1211
# epoch-25 testing finished , loss_ave_val = 0.1589
# epoch-26 training finished , loss_ave_train = 0.1193
# epoch-26 testing finished , loss_ave_val = 0.1587
# epoch-27 training finished , loss_ave_train = 0.1178
# epoch-27 testing finished , loss_ave_val = 0.1591
# epoch-28 training finished , loss_ave_train = 0.1179
# epoch-28 testing finished , loss_ave_val = 0.1677
# epoch-29 training finished , loss_ave_train = 0.1139
# epoch-29 testing finished , loss_ave_val = 0.1633
# epoch-30 training finished , loss_ave_train = 0.1132
# epoch-30 testing finished , loss_ave_val = 0.1625
# ***get the model NetMHCpan_10_LSTM_fold3***
# epoch-1 training finished , loss_ave_train = 0.2246
# epoch-1 testing finished , loss_ave_val = 0.1917
# epoch-2 training finished , loss_ave_train = 0.1822
# epoch-2 testing finished , loss_ave_val = 0.1853
# epoch-3 training finished , loss_ave_train = 0.1720
# epoch-3 testing finished , loss_ave_val = 0.1828
# epoch-4 training finished , loss_ave_train = 0.1674
# epoch-4 testing finished , loss_ave_val = 0.1802
# epoch-5 training finished , loss_ave_train = 0.1637
# epoch-5 testing finished , loss_ave_val = 0.1779
# epoch-6 training finished , loss_ave_train = 0.1618
# epoch-6 testing finished , loss_ave_val = 0.1776
# epoch-7 training finished , loss_ave_train = 0.1591
# epoch-7 testing finished , loss_ave_val = 0.1776
# epoch-8 training finished , loss_ave_train = 0.1560
# epoch-8 testing finished , loss_ave_val = 0.1762
# epoch-9 training finished , loss_ave_train = 0.1532
# epoch-9 testing finished , loss_ave_val = 0.1751
# epoch-10 training finished , loss_ave_train = 0.1496
# epoch-10 testing finished , loss_ave_val = 0.1733
# epoch-11 training finished , loss_ave_train = 0.1474
# epoch-11 testing finished , loss_ave_val = 0.1729
# epoch-12 training finished , loss_ave_train = 0.1441
# epoch-12 testing finished , loss_ave_val = 0.1728
# epoch-13 training finished , loss_ave_train = 0.1417
# epoch-13 testing finished , loss_ave_val = 0.1767
# epoch-14 training finished , loss_ave_train = 0.1404
# epoch-14 testing finished , loss_ave_val = 0.1788
# epoch-15 training finished , loss_ave_train = 0.1381
# epoch-15 testing finished , loss_ave_val = 0.1784
# epoch-16 training finished , loss_ave_train = 0.1364
# epoch-16 testing finished , loss_ave_val = 0.1775
# epoch-17 training finished , loss_ave_train = 0.1356
# epoch-17 testing finished , loss_ave_val = 0.1829
# epoch-18 training finished , loss_ave_train = 0.1337
# epoch-18 testing finished , loss_ave_val = 0.1836
# epoch-19 training finished , loss_ave_train = 0.1292
# epoch-19 testing finished , loss_ave_val = 0.1847
# epoch-20 training finished , loss_ave_train = 0.1299
# epoch-20 testing finished , loss_ave_val = 0.1930
# epoch-21 training finished , loss_ave_train = 0.1250
# epoch-21 testing finished , loss_ave_val = 0.1923
# epoch-22 training finished , loss_ave_train = 0.1231
# epoch-22 testing finished , loss_ave_val = 0.2016
# epoch-23 training finished , loss_ave_train = 0.1207
# epoch-23 testing finished , loss_ave_val = 0.2089
# epoch-24 training finished , loss_ave_train = 0.1243
# epoch-24 testing finished , loss_ave_val = 0.1974
# epoch-25 training finished , loss_ave_train = 0.1171
# epoch-25 testing finished , loss_ave_val = 0.2055
# epoch-26 training finished , loss_ave_train = 0.1165
# epoch-26 testing finished , loss_ave_val = 0.1966
# epoch-27 training finished , loss_ave_train = 0.1159
# epoch-27 testing finished , loss_ave_val = 0.1939
# epoch-28 training finished , loss_ave_train = 0.1132
# epoch-28 testing finished , loss_ave_val = 0.2010
# epoch-29 training finished , loss_ave_train = 0.1115
# epoch-29 testing finished , loss_ave_val = 0.1992
# epoch-30 training finished , loss_ave_train = 0.1096
# epoch-30 testing finished , loss_ave_val = 0.2015
# ***get the model NetMHCpan_10_LSTM_fold4***

# %%
#平均评估loss
epoch = [e+1 for e in range(epoch_num)]
loss_val_ave = []
for e in range(epoch_num):
    sum = 0
    for n in range(fold):
        sum += loss_val_sum[n*epoch_num + e]
    loss_val_ave.append(sum/fold)
plt.figure(fold+1)
plt.plot(epoch, loss_val_ave, marker='o', markersize=3)
plt.xlabel('epoch'),plt.ylabel('loss')
plt.title("model's validation result")
# Out:
# Text(0.5, 1.0, "model's validation result")

# %% [markdown]
# fold3 is better

# %% [markdown]
# ##### 在其他data_set上的accuracy

# %%
#independent_set
import pandas as pd
import numpy as np
import torch

'''BLOSUM50'''
BLOSUM50_Matrix = pd.read_table('BLOSUM50_Matrix.txt',sep = '\s+')          #用\s+,如果用\t会让txt中第一列会被当作数据
amino_acid_sort = ['A','R','N','D','C','Q','E','G','H','I','L','K','M','F','P','S','T','W','Y','V','B','J','Z','X']    #X可以用于padding
amino_acid_num = len(amino_acid_sort)
BLOSUM50_Matrix = BLOSUM50_Matrix.loc[amino_acid_sort, amino_acid_sort]     #去掉BLOSUM50中的*

#参数
pep_len_max = 14
HLA_len = 34

embedding_dim = amino_acid_num
lstm_hidden_size = 16                                   #16 from paper
hidden_size = 60                                        #60 from paper
output_size = 1                                         #a single neroun

fold = 5

#设备
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')       #有GPU就用GPU

'''提取数据'''
pep_data = pd.read_csv("data_csv/independent_set2.csv",usecols=["peptide","length"]) 
HLA_data = pd.read_csv("data_csv/independent_set2.csv",usecols=["HLA_sequence"]) 
bind_data = pd.read_csv("data_csv/independent_set2.csv",usecols=["label"]) 

pep_seq, pep_len, pep_len_max= np.array(pep_data["peptide"]), np.array(pep_data["length"]), 14
HLA_seq, HLA_len = np.array(HLA_data["HLA_sequence"]), 34
bind_label = np.array(bind_data["label"])

data_num = bind_label.size          #数据数量

'''加载模型'''
use_model = torch.load("model/NetMHCpan_10_LSTM_fold3.pkl")

'''预测'''
pre_result = np.zeros(data_num)

for i in range(data_num):

    '''先编码'''
    pep_code = np.zeros((pep_len_max, amino_acid_num))
    HLA_code = np.zeros((HLA_len, amino_acid_num))

    for j in range(pep_len[i]):
        pep_code[j,:] = BLOSUM50_Matrix[pep_seq[i][j]]              #先对peptide编码

    for j in range(pep_len[i], pep_len_max):
        pep_code[j,:] = BLOSUM50_Matrix['X']                        #peptide长度不足14，padding，用X编码 

    for j in range(HLA_len):
        HLA_code[j,:] = BLOSUM50_Matrix[HLA_seq[i][j]]              #最后对HLA序列编码，放在后面
            
    pep_code = pep_code.reshape(-1, 1, embedding_dim)               #lstm input: shape = [seq_length, batch_size, input_size]的张量
    HLA_code = HLA_code.reshape(-1, 1, embedding_dim)               #batch_size = 1           

    '''前向传播，得到预测'''
    pep_code = torch.Tensor(pep_code).to(device)                    #输入GPU
    HLA_code = torch.Tensor(HLA_code).to(device)

    target = bind_label[i]
    target = target.reshape(-1,1)
    target = torch.Tensor(target).to(device, dtype = torch.float)   #MSE backward()中要求是float，不是long

    prediction = use_model(pep_code, HLA_code)
    pre_result[i] = prediction.item()

'''probability--->binding(1) or non-binding(0)'''
pre_result[pre_result >= 0.5] = 1
pre_result[pre_result < 0.5] = 0

'''prediction与label比较'''
pre_result[pre_result != bind_label] = 0    #用pre_result保存比较结果
pre_result[pre_result == bind_label] = 1

correct_num = np.sum(pre_result)
accuracy = correct_num/data_num
print("accuracy on independent_set is {:.4f}".format(accuracy))
# Out:
# accuracy on independent_set is 0.9156

# %%
#external_set
'''BLOSUM50'''
BLOSUM50_Matrix = pd.read_table('BLOSUM50_Matrix.txt',sep = '\s+')          #用\s+,如果用\t会让txt中第一列会被当作数据
amino_acid_sort = ['A','R','N','D','C','Q','E','G','H','I','L','K','M','F','P','S','T','W','Y','V','B','J','Z','X']    #X可以用于padding
amino_acid_num = len(amino_acid_sort)
BLOSUM50_Matrix = BLOSUM50_Matrix.loc[amino_acid_sort, amino_acid_sort]     #去掉BLOSUM50中的*

'''提取数据'''
pep_data = pd.read_csv("data_csv/external_set2.csv",usecols=["peptide","length"]) 
HLA_data = pd.read_csv("data_csv/external_set2.csv",usecols=["HLA_sequence"]) 
bind_data = pd.read_csv("data_csv/external_set2.csv",usecols=["label"]) 

pep_seq, pep_len, pep_len_max= np.array(pep_data["peptide"]), np.array(pep_data["length"]), 14
HLA_seq, HLA_len = np.array(HLA_data["HLA_sequence"]), 34
bind_label = np.array(bind_data["label"])

data_num = bind_label.size          #数据数量

'''加载模型'''
use_model = torch.load("model/NetMHCpan_10_LSTM_fold3.pkl")

'''预测'''
pre_result = np.zeros(data_num)

for i in range(data_num):

    '''先编码'''
    pep_code = np.zeros((pep_len_max, amino_acid_num))
    HLA_code = np.zeros((HLA_len, amino_acid_num))

    for j in range(pep_len[i]):
        pep_code[j,:] = BLOSUM50_Matrix[pep_seq[i][j]]              #先对peptide编码

    for j in range(pep_len[i], pep_len_max):
        pep_code[j,:] = BLOSUM50_Matrix['X']                        #peptide长度不足14，padding，用X编码 

    for j in range(HLA_len):
        HLA_code[j,:] = BLOSUM50_Matrix[HLA_seq[i][j]]              #最后对HLA序列编码，放在后面
            
    pep_code = pep_code.reshape(-1, 1, embedding_dim)               #lstm input: shape = [seq_length, batch_size, input_size]的张量
    HLA_code = HLA_code.reshape(-1, 1, embedding_dim)               #batch_size = 1           

    '''前向传播，得到预测'''
    pep_code = torch.Tensor(pep_code).to(device)                    #输入GPU
    HLA_code = torch.Tensor(HLA_code).to(device)

    target = bind_label[i]
    target = target.reshape(-1,1)
    target = torch.Tensor(target).to(device, dtype = torch.float)   #MSE backward()中要求是float，不是long

    prediction = use_model(pep_code, HLA_code)
    pre_result[i] = prediction.item()

'''probability--->binding(1) or non-binding(0)'''
pre_result[pre_result >= 0.5] = 1
pre_result[pre_result < 0.5] = 0

'''prediction与label比较'''
pre_result[pre_result != bind_label] = 0    #用pre_result保存比较结果
pre_result[pre_result == bind_label] = 1

correct_num = np.sum(pre_result)
accuracy = correct_num/data_num
print("accuracy on external_set is {}".format(accuracy))
# Out:
# accuracy on external_set is 0.922

# %% [markdown]
# fold0/1/2/3 都是0.85以上

# %% [markdown]
# ##### 如果不对peptide填充，训练结果会怎样

# %%
import pandas as pd
import numpy as np

import torch
import task_models
import torch.nn as nn
import torch.optim as optim

import matplotlib.pyplot as plt

'''BLOSUM50'''
BLOSUM50_Matrix = pd.read_table('BLOSUM50_Matrix.txt',sep = '\s+')          #用\s+,如果用\t会让txt中第一列会被当作数据
amino_acid_sort = ['A','R','N','D','C','Q','E','G','H','I','L','K','M','F','P','S','T','W','Y','V','B','J','Z','X']    #X可以用于padding
amino_acid_num = len(amino_acid_sort)
BLOSUM50_Matrix = BLOSUM50_Matrix.loc[amino_acid_sort, amino_acid_sort]     #去掉BLOSUM50中的*

'''训练'''
#参数
pep_len_max = 14
HLA_len = 34

embedding_dim = amino_acid_num
lstm_hidden_size = 16                                   #16 from paper
hidden_size = 60                                        #60 from paper
output_size = 1                                         #a single neroun

epoch_num = 30
learning_rate = 0.0005

fold = 5

#设备
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')       #有GPU就用GPU

loss_val_sum = []           #保存每个epoch中，5个模型平均评估loss之和，用于计算最后的平均结果

#开始 5fold-cv 训练
for f in range(fold):

    #模型
    model = task_models.NetMHCpan_10_LSTM(embedding_dim, embedding_dim, lstm_hidden_size, hidden_size, output_size).to(device)

    #优化方式
    loss_fn = nn.MSELoss()                                               #MSE-loss
    optimizer = optim.Adam(model.parameters(), lr = learning_rate)       #Adam优化方式

    train_data_num = [n for n in range(fold)]   #训练数据编号
    train_data_num.pop(f)                       #拿出一组训练数据用于评估，其余用于训练

    loss_ave_train = []         #保存每个epoch的平均训练loss
    loss_ave_val = []           #保存每个epoch的平均评估loss

    #训练30个epoch
    for e in range(epoch_num):

        #训练模型
        loss_all_train = []       #保存1个epoch中每个数据的loss

        #用训练数据训练
        for ff in train_data_num:
            '''提取数据'''
            pep_data = pd.read_csv("data_csv/train_data_fold{}.csv".format(ff),usecols=["peptide","length"]) 
            HLA_data = pd.read_csv("data_csv/train_data_fold{}.csv".format(ff),usecols=["HLA_sequence"]) 
            bind_data = pd.read_csv("data_csv/train_data_fold{}.csv".format(ff),usecols=["label"]) 

            pep_seq, pep_len = np.array(pep_data["peptide"]), np.array(pep_data["length"])
            HLA_seq = np.array(HLA_data["HLA_sequence"])
            bind_label = np.array(bind_data["label"])

            data_num = bind_label.size          #数据数量

            for i in range(data_num):

                '''先编码'''
                pep_code = np.zeros((pep_len_max, amino_acid_num))
                HLA_code = np.zeros((HLA_len, amino_acid_num))

                for j in range(pep_len[i]):
                    pep_code[j,:] = BLOSUM50_Matrix[pep_seq[i][j]]              #对peptide编码，不填充

                for j in range(HLA_len):
                    HLA_code[j,:] = BLOSUM50_Matrix[HLA_seq[i][j]]              #对HLA序列编码
                
                pep_code = pep_code.reshape(-1, 1, embedding_dim)               #lstm input: shape = [seq_length, batch_size, input_size]的张量
                HLA_code = HLA_code.reshape(-1, 1, embedding_dim)               #batch_size = 1

                '''前向传播，得到预测与误差'''
                pep_code = torch.Tensor(pep_code).to(device)                    #输入GPU
                HLA_code = torch.Tensor(HLA_code).to(device)

                target = bind_label[i]
                target = target.reshape(-1,1)
                target = torch.Tensor(target).to(device, dtype = torch.float)   #MSE backward()中要求是float，不是long

                prediction = model(pep_code, HLA_code)                         
                loss = loss_fn(prediction, target)
                loss_all_train.append(loss.item())

                '''后向传播，更新模型参数'''
                optimizer.zero_grad()   #梯度清零
                loss.backward()         #计算梯度
                optimizer.step()        #更新参数

        loss_ave_train.append(np.mean(loss_all_train))
        print('epoch-{} training finished , loss_ave_train = {:.4f}'.format(e+1, np.mean(loss_all_train)))


        #用剩余的一组数据评估模型
        loss_all_val = []       #保存1个epoch中每个数据的loss

        '''提取数据'''
        pep_data = pd.read_csv("data_csv/train_data_fold{}.csv".format(f),usecols=["peptide","length"]) 
        HLA_data = pd.read_csv("data_csv/train_data_fold{}.csv".format(f),usecols=["HLA_sequence"]) 
        bind_data = pd.read_csv("data_csv/train_data_fold{}.csv".format(f),usecols=["label"]) 

        pep_seq, pep_len, pep_len_max= np.array(pep_data["peptide"]), np.array(pep_data["length"]), 14
        HLA_seq, HLA_len = np.array(HLA_data["HLA_sequence"]), 34
        bind_label = np.array(bind_data["label"])

        data_num = bind_label.size          #数据数量

        for i in range(data_num):

            '''先编码'''
            pep_code = np.zeros((pep_len_max, amino_acid_num))
            HLA_code = np.zeros((HLA_len, amino_acid_num))

            for j in range(pep_len[i]):
                pep_code[j,:] = BLOSUM50_Matrix[pep_seq[i][j]]              #对peptide编码

            for j in range(HLA_len):
                HLA_code[j,:] = BLOSUM50_Matrix[HLA_seq[i][j]]              #对HLA序列编码
            
            pep_code = pep_code.reshape(-1, 1, embedding_dim)               #lstm input: shape = [seq_length, batch_size, input_size]的张量
            HLA_code = HLA_code.reshape(-1, 1, embedding_dim)               #batch_size = 1           

            '''前向传播，得到预测与误差'''
            pep_code = torch.Tensor(pep_code).to(device)                    #输入GPU
            HLA_code = torch.Tensor(HLA_code).to(device)

            target = bind_label[i]
            target = target.reshape(-1,1)
            target = torch.Tensor(target).to(device, dtype = torch.float)   #MSE backward()中要求是float，不是long

            prediction = model.forward(pep_code, HLA_code)
            loss = loss_fn(prediction, target)
            loss_all_val.append(loss.item())

        loss_ave_val.append(np.mean(loss_all_val))
        print('epoch-{} testing finished , loss_ave_val = {:.4f}'.format(e+1, np.mean(loss_all_val)))
    
    loss_val_sum += loss_ave_val

    #作图，画出loss-epoch折线
    epoch = [e+1 for e in range(epoch_num)]

    plt.figure(f+1)
    plt.plot(epoch, loss_ave_train, marker='o', markersize=2)
    plt.plot(epoch, loss_ave_val, marker='o', markersize=2)
    plt.ylim(0.05, 0.35)
    plt.legend(['train','val'])
    plt.xlabel('epoch'),plt.ylabel('loss_ave')
    plt.title("fold{} as val_data".format(f))

    #保存当前模型
    torch.save(model, "model/NetMHCpan_10_LSTM2_fold{}.pkl".format(f))
    print("***get the model NetMHCpan_10_LSTM2_fold{}***".format(f))
# Out:
# epoch-1 training finished , loss_ave_train = 0.2035
# epoch-1 testing finished , loss_ave_val = 0.1894
# epoch-2 training finished , loss_ave_train = 0.1665
# epoch-2 testing finished , loss_ave_val = 0.1856
# epoch-3 training finished , loss_ave_train = 0.1621
# epoch-3 testing finished , loss_ave_val = 0.1833
# epoch-4 training finished , loss_ave_train = 0.1576
# epoch-4 testing finished , loss_ave_val = 0.1819
# epoch-5 training finished , loss_ave_train = 0.1539
# epoch-5 testing finished , loss_ave_val = 0.1849
# epoch-6 training finished , loss_ave_train = 0.1510
# epoch-6 testing finished , loss_ave_val = 0.1844
# epoch-7 training finished , loss_ave_train = 0.1483
# epoch-7 testing finished , loss_ave_val = 0.1865
# epoch-8 training finished , loss_ave_train = 0.1461
# epoch-8 testing finished , loss_ave_val = 0.1873
# epoch-9 training finished , loss_ave_train = 0.1442
# epoch-9 testing finished , loss_ave_val = 0.1866
# epoch-10 training finished , loss_ave_train = 0.1422
# epoch-10 testing finished , loss_ave_val = 0.1860
# epoch-11 training finished , loss_ave_train = 0.1403
# epoch-11 testing finished , loss_ave_val = 0.1894
# epoch-12 training finished , loss_ave_train = 0.1386
# epoch-12 testing finished , loss_ave_val = 0.1905
# epoch-13 training finished , loss_ave_train = 0.1359
# epoch-13 testing finished , loss_ave_val = 0.1915
# epoch-14 training finished , loss_ave_train = 0.1335
# epoch-14 testing finished , loss_ave_val = 0.1945
# epoch-15 training finished , loss_ave_train = 0.1309
# epoch-15 testing finished , loss_ave_val = 0.1983
# epoch-16 training finished , loss_ave_train = 0.1284
# epoch-16 testing finished , loss_ave_val = 0.1999
# epoch-17 training finished , loss_ave_train = 0.1260
# epoch-17 testing finished , loss_ave_val = 0.2014
# epoch-18 training finished , loss_ave_train = 0.1239
# epoch-18 testing finished , loss_ave_val = 0.1995
# epoch-19 training finished , loss_ave_train = 0.1217
# epoch-19 testing finished , loss_ave_val = 0.1993
# epoch-20 training finished , loss_ave_train = 0.1196
# epoch-20 testing finished , loss_ave_val = 0.1993
# epoch-21 training finished , loss_ave_train = 0.1176
# epoch-21 testing finished , loss_ave_val = 0.2003
# epoch-22 training finished , loss_ave_train = 0.1157
# epoch-22 testing finished , loss_ave_val = 0.2026
# epoch-23 training finished , loss_ave_train = 0.1136
# epoch-23 testing finished , loss_ave_val = 0.2033
# epoch-24 training finished , loss_ave_train = 0.1119
# epoch-24 testing finished , loss_ave_val = 0.2038
# epoch-25 training finished , loss_ave_train = 0.1104
# epoch-25 testing finished , loss_ave_val = 0.2036
# epoch-26 training finished , loss_ave_train = 0.1083
# epoch-26 testing finished , loss_ave_val = 0.2062
# epoch-27 training finished , loss_ave_train = 0.1070
# epoch-27 testing finished , loss_ave_val = 0.2053
# epoch-28 training finished , loss_ave_train = 0.1048
# epoch-28 testing finished , loss_ave_val = 0.2044
# epoch-29 training finished , loss_ave_train = 0.1034
# epoch-29 testing finished , loss_ave_val = 0.2053
# epoch-30 training finished , loss_ave_train = 0.1015
# epoch-30 testing finished , loss_ave_val = 0.2043
# ***get the model NetMHCpan_10_LSTM2_fold0***
# epoch-1 training finished , loss_ave_train = 0.2034
# epoch-1 testing finished , loss_ave_val = 0.1758
# epoch-2 training finished , loss_ave_train = 0.1682
# epoch-2 testing finished , loss_ave_val = 0.1723
# epoch-3 training finished , loss_ave_train = 0.1619
# epoch-3 testing finished , loss_ave_val = 0.1733
# epoch-4 training finished , loss_ave_train = 0.1573
# epoch-4 testing finished , loss_ave_val = 0.1721
# epoch-5 training finished , loss_ave_train = 0.1536
# epoch-5 testing finished , loss_ave_val = 0.1699
# epoch-6 training finished , loss_ave_train = 0.1497
# epoch-6 testing finished , loss_ave_val = 0.1674
# epoch-7 training finished , loss_ave_train = 0.1465
# epoch-7 testing finished , loss_ave_val = 0.1658
# epoch-8 training finished , loss_ave_train = 0.1434
# epoch-8 testing finished , loss_ave_val = 0.1637
# epoch-9 training finished , loss_ave_train = 0.1405
# epoch-9 testing finished , loss_ave_val = 0.1633
# epoch-10 training finished , loss_ave_train = 0.1378
# epoch-10 testing finished , loss_ave_val = 0.1625
# epoch-11 training finished , loss_ave_train = 0.1351
# epoch-11 testing finished , loss_ave_val = 0.1667
# epoch-12 training finished , loss_ave_train = 0.1323
# epoch-12 testing finished , loss_ave_val = 0.1680
# epoch-13 training finished , loss_ave_train = 0.1295
# epoch-13 testing finished , loss_ave_val = 0.1691
# epoch-14 training finished , loss_ave_train = 0.1264
# epoch-14 testing finished , loss_ave_val = 0.1681
# epoch-15 training finished , loss_ave_train = 0.1237
# epoch-15 testing finished , loss_ave_val = 0.1698
# epoch-16 training finished , loss_ave_train = 0.1208
# epoch-16 testing finished , loss_ave_val = 0.1706
# epoch-17 training finished , loss_ave_train = 0.1181
# epoch-17 testing finished , loss_ave_val = 0.1712
# epoch-18 training finished , loss_ave_train = 0.1146
# epoch-18 testing finished , loss_ave_val = 0.1725
# epoch-19 training finished , loss_ave_train = 0.1120
# epoch-19 testing finished , loss_ave_val = 0.1710
# epoch-20 training finished , loss_ave_train = 0.1088
# epoch-20 testing finished , loss_ave_val = 0.1708
# epoch-21 training finished , loss_ave_train = 0.1057
# epoch-21 testing finished , loss_ave_val = 0.1690
# epoch-22 training finished , loss_ave_train = 0.1026
# epoch-22 testing finished , loss_ave_val = 0.1681
# epoch-23 training finished , loss_ave_train = 0.0981
# epoch-23 testing finished , loss_ave_val = 0.1723
# epoch-24 training finished , loss_ave_train = 0.0954
# epoch-24 testing finished , loss_ave_val = 0.1724
# epoch-25 training finished , loss_ave_train = 0.0939
# epoch-25 testing finished , loss_ave_val = 0.1718
# epoch-26 training finished , loss_ave_train = 0.0893
# epoch-26 testing finished , loss_ave_val = 0.1693
# epoch-27 training finished , loss_ave_train = 0.0852
# epoch-27 testing finished , loss_ave_val = 0.1748
# epoch-28 training finished , loss_ave_train = 0.0837
# epoch-28 testing finished , loss_ave_val = 0.1801
# epoch-29 training finished , loss_ave_train = 0.0813
# epoch-29 testing finished , loss_ave_val = 0.1789
# epoch-30 training finished , loss_ave_train = 0.0775
# epoch-30 testing finished , loss_ave_val = 0.1820
# ***get the model NetMHCpan_10_LSTM2_fold1***
# epoch-1 training finished , loss_ave_train = 0.1938
# epoch-1 testing finished , loss_ave_val = 0.1934
# epoch-2 training finished , loss_ave_train = 0.1656
# epoch-2 testing finished , loss_ave_val = 0.1866
# epoch-3 training finished , loss_ave_train = 0.1599
# epoch-3 testing finished , loss_ave_val = 0.1868
# epoch-4 training finished , loss_ave_train = 0.1560
# epoch-4 testing finished , loss_ave_val = 0.1870
# epoch-5 training finished , loss_ave_train = 0.1523
# epoch-5 testing finished , loss_ave_val = 0.1881
# epoch-6 training finished , loss_ave_train = 0.1490
# epoch-6 testing finished , loss_ave_val = 0.1899
# epoch-7 training finished , loss_ave_train = 0.1459
# epoch-7 testing finished , loss_ave_val = 0.1912
# epoch-8 training finished , loss_ave_train = 0.1431
# epoch-8 testing finished , loss_ave_val = 0.1912
# epoch-9 training finished , loss_ave_train = 0.1399
# epoch-9 testing finished , loss_ave_val = 0.1924
# epoch-10 training finished , loss_ave_train = 0.1370
# epoch-10 testing finished , loss_ave_val = 0.1965
# epoch-11 training finished , loss_ave_train = 0.1339
# epoch-11 testing finished , loss_ave_val = 0.1960
# epoch-12 training finished , loss_ave_train = 0.1312
# epoch-12 testing finished , loss_ave_val = 0.1972
# epoch-13 training finished , loss_ave_train = 0.1285
# epoch-13 testing finished , loss_ave_val = 0.1978
# epoch-14 training finished , loss_ave_train = 0.1262
# epoch-14 testing finished , loss_ave_val = 0.1979
# epoch-15 training finished , loss_ave_train = 0.1240
# epoch-15 testing finished , loss_ave_val = 0.1991
# epoch-16 training finished , loss_ave_train = 0.1218
# epoch-16 testing finished , loss_ave_val = 0.1998
# epoch-17 training finished , loss_ave_train = 0.1195
# epoch-17 testing finished , loss_ave_val = 0.2010
# epoch-18 training finished , loss_ave_train = 0.1169
# epoch-18 testing finished , loss_ave_val = 0.2010
# epoch-19 training finished , loss_ave_train = 0.1142
# epoch-19 testing finished , loss_ave_val = 0.2019
# epoch-20 training finished , loss_ave_train = 0.1119
# epoch-20 testing finished , loss_ave_val = 0.2027
# epoch-21 training finished , loss_ave_train = 0.1097
# epoch-21 testing finished , loss_ave_val = 0.2040
# epoch-22 training finished , loss_ave_train = 0.1076
# epoch-22 testing finished , loss_ave_val = 0.2050
# epoch-23 training finished , loss_ave_train = 0.1052
# epoch-23 testing finished , loss_ave_val = 0.2048
# epoch-24 training finished , loss_ave_train = 0.1035
# epoch-24 testing finished , loss_ave_val = 0.2069
# epoch-25 training finished , loss_ave_train = 0.1016
# epoch-25 testing finished , loss_ave_val = 0.2058
# epoch-26 training finished , loss_ave_train = 0.0994
# epoch-26 testing finished , loss_ave_val = 0.2045
# epoch-27 training finished , loss_ave_train = 0.0975
# epoch-27 testing finished , loss_ave_val = 0.2051
# epoch-28 training finished , loss_ave_train = 0.0961
# epoch-28 testing finished , loss_ave_val = 0.2038
# epoch-29 training finished , loss_ave_train = 0.0943
# epoch-29 testing finished , loss_ave_val = 0.2046
# epoch-30 training finished , loss_ave_train = 0.0933
# epoch-30 testing finished , loss_ave_val = 0.2062
# ***get the model NetMHCpan_10_LSTM2_fold2***
# epoch-1 training finished , loss_ave_train = 0.2079
# epoch-1 testing finished , loss_ave_val = 0.1775
# epoch-2 training finished , loss_ave_train = 0.1736
# epoch-2 testing finished , loss_ave_val = 0.1660
# epoch-3 training finished , loss_ave_train = 0.1670
# epoch-3 testing finished , loss_ave_val = 0.1608
# epoch-4 training finished , loss_ave_train = 0.1628
# epoch-4 testing finished , loss_ave_val = 0.1592
# epoch-5 training finished , loss_ave_train = 0.1592
# epoch-5 testing finished , loss_ave_val = 0.1590
# epoch-6 training finished , loss_ave_train = 0.1562
# epoch-6 testing finished , loss_ave_val = 0.1597
# epoch-7 training finished , loss_ave_train = 0.1538
# epoch-7 testing finished , loss_ave_val = 0.1595
# epoch-8 training finished , loss_ave_train = 0.1517
# epoch-8 testing finished , loss_ave_val = 0.1596
# epoch-9 training finished , loss_ave_train = 0.1494
# epoch-9 testing finished , loss_ave_val = 0.1590
# epoch-10 training finished , loss_ave_train = 0.1474
# epoch-10 testing finished , loss_ave_val = 0.1595
# epoch-11 training finished , loss_ave_train = 0.1450
# epoch-11 testing finished , loss_ave_val = 0.1585
# epoch-12 training finished , loss_ave_train = 0.1425
# epoch-12 testing finished , loss_ave_val = 0.1580
# epoch-13 training finished , loss_ave_train = 0.1400
# epoch-13 testing finished , loss_ave_val = 0.1580
# epoch-14 training finished , loss_ave_train = 0.1377
# epoch-14 testing finished , loss_ave_val = 0.1587
# epoch-15 training finished , loss_ave_train = 0.1348
# epoch-15 testing finished , loss_ave_val = 0.1602
# epoch-16 training finished , loss_ave_train = 0.1322
# epoch-16 testing finished , loss_ave_val = 0.1611
# epoch-17 training finished , loss_ave_train = 0.1293
# epoch-17 testing finished , loss_ave_val = 0.1632
# epoch-18 training finished , loss_ave_train = 0.1263
# epoch-18 testing finished , loss_ave_val = 0.1659
# epoch-19 training finished , loss_ave_train = 0.1235
# epoch-19 testing finished , loss_ave_val = 0.1681
# epoch-20 training finished , loss_ave_train = 0.1205
# epoch-20 testing finished , loss_ave_val = 0.1714
# epoch-21 training finished , loss_ave_train = 0.1176
# epoch-21 testing finished , loss_ave_val = 0.1741
# epoch-22 training finished , loss_ave_train = 0.1147
# epoch-22 testing finished , loss_ave_val = 0.1768
# epoch-23 training finished , loss_ave_train = 0.1119
# epoch-23 testing finished , loss_ave_val = 0.1811
# epoch-24 training finished , loss_ave_train = 0.1091
# epoch-24 testing finished , loss_ave_val = 0.1831
# epoch-25 training finished , loss_ave_train = 0.1068
# epoch-25 testing finished , loss_ave_val = 0.1849
# epoch-26 training finished , loss_ave_train = 0.1044
# epoch-26 testing finished , loss_ave_val = 0.1848
# epoch-27 training finished , loss_ave_train = 0.1020
# epoch-27 testing finished , loss_ave_val = 0.1878
# epoch-28 training finished , loss_ave_train = 0.0998
# epoch-28 testing finished , loss_ave_val = 0.1889
# epoch-29 training finished , loss_ave_train = 0.0970
# epoch-29 testing finished , loss_ave_val = 0.1893
# epoch-30 training finished , loss_ave_train = 0.0956
# epoch-30 testing finished , loss_ave_val = 0.1937
# ***get the model NetMHCpan_10_LSTM2_fold3***
# epoch-1 training finished , loss_ave_train = 0.1972
# epoch-1 testing finished , loss_ave_val = 0.1850
# epoch-2 training finished , loss_ave_train = 0.1648
# epoch-2 testing finished , loss_ave_val = 0.1787
# epoch-3 training finished , loss_ave_train = 0.1597
# epoch-3 testing finished , loss_ave_val = 0.1758
# epoch-4 training finished , loss_ave_train = 0.1556
# epoch-4 testing finished , loss_ave_val = 0.1741
# epoch-5 training finished , loss_ave_train = 0.1519
# epoch-5 testing finished , loss_ave_val = 0.1725
# epoch-6 training finished , loss_ave_train = 0.1489
# epoch-6 testing finished , loss_ave_val = 0.1714
# epoch-7 training finished , loss_ave_train = 0.1461
# epoch-7 testing finished , loss_ave_val = 0.1716
# epoch-8 training finished , loss_ave_train = 0.1434
# epoch-8 testing finished , loss_ave_val = 0.1723
# epoch-9 training finished , loss_ave_train = 0.1410
# epoch-9 testing finished , loss_ave_val = 0.1736
# epoch-10 training finished , loss_ave_train = 0.1389
# epoch-10 testing finished , loss_ave_val = 0.1746
# epoch-11 training finished , loss_ave_train = 0.1367
# epoch-11 testing finished , loss_ave_val = 0.1754
# epoch-12 training finished , loss_ave_train = 0.1345
# epoch-12 testing finished , loss_ave_val = 0.1765
# epoch-13 training finished , loss_ave_train = 0.1324
# epoch-13 testing finished , loss_ave_val = 0.1774
# epoch-14 training finished , loss_ave_train = 0.1300
# epoch-14 testing finished , loss_ave_val = 0.1795
# epoch-15 training finished , loss_ave_train = 0.1278
# epoch-15 testing finished , loss_ave_val = 0.1811
# epoch-16 training finished , loss_ave_train = 0.1254
# epoch-16 testing finished , loss_ave_val = 0.1840
# epoch-17 training finished , loss_ave_train = 0.1230
# epoch-17 testing finished , loss_ave_val = 0.1869
# epoch-18 training finished , loss_ave_train = 0.1208
# epoch-18 testing finished , loss_ave_val = 0.1893
# epoch-19 training finished , loss_ave_train = 0.1185
# epoch-19 testing finished , loss_ave_val = 0.1918
# epoch-20 training finished , loss_ave_train = 0.1159
# epoch-20 testing finished , loss_ave_val = 0.1953
# epoch-21 training finished , loss_ave_train = 0.1129
# epoch-21 testing finished , loss_ave_val = 0.1994
# epoch-22 training finished , loss_ave_train = 0.1097
# epoch-22 testing finished , loss_ave_val = 0.2056
# epoch-23 training finished , loss_ave_train = 0.1065
# epoch-23 testing finished , loss_ave_val = 0.2091
# epoch-24 training finished , loss_ave_train = 0.1036
# epoch-24 testing finished , loss_ave_val = 0.2123
# epoch-25 training finished , loss_ave_train = 0.1005
# epoch-25 testing finished , loss_ave_val = 0.2138
# epoch-26 training finished , loss_ave_train = 0.0984
# epoch-26 testing finished , loss_ave_val = 0.2145
# epoch-27 training finished , loss_ave_train = 0.0972
# epoch-27 testing finished , loss_ave_val = 0.2140
# epoch-28 training finished , loss_ave_train = 0.0942
# epoch-28 testing finished , loss_ave_val = 0.2143
# epoch-29 training finished , loss_ave_train = 0.0927
# epoch-29 testing finished , loss_ave_val = 0.2156
# epoch-30 training finished , loss_ave_train = 0.0914
# epoch-30 testing finished , loss_ave_val = 0.2121
# ***get the model NetMHCpan_10_LSTM2_fold4***

# %%
#independent_set
import pandas as pd
import numpy as np
import torch

#参数
pep_len_max = 14
HLA_len = 34

embedding_dim = amino_acid_num
lstm_hidden_size = 16                                   #16 from paper
hidden_size = 60                                        #60 from paper
output_size = 1                                         #a single neroun

fold = 5

#设备
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')       #有GPU就用GPU

'''BLOSUM50'''
BLOSUM50_Matrix = pd.read_table('BLOSUM50_Matrix.txt',sep = '\s+')          #用\s+,如果用\t会让txt中第一列会被当作数据
amino_acid_sort = ['A','R','N','D','C','Q','E','G','H','I','L','K','M','F','P','S','T','W','Y','V','B','J','Z','X']    #X可以用于padding
amino_acid_num = len(amino_acid_sort)
BLOSUM50_Matrix = BLOSUM50_Matrix.loc[amino_acid_sort, amino_acid_sort]     #去掉BLOSUM50中的*

'''提取数据'''
pep_data = pd.read_csv("data_csv/independent_set2.csv",usecols=["peptide","length"]) 
HLA_data = pd.read_csv("data_csv/independent_set2.csv",usecols=["HLA_sequence"]) 
bind_data = pd.read_csv("data_csv/independent_set2.csv",usecols=["label"]) 

pep_seq, pep_len, pep_len_max= np.array(pep_data["peptide"]), np.array(pep_data["length"]), 14
HLA_seq, HLA_len = np.array(HLA_data["HLA_sequence"]), 34
bind_label = np.array(bind_data["label"])

data_num = bind_label.size          #数据数量

'''加载模型'''
use_model = torch.load("model/NetMHCpan_10_LSTM2_fold2.pkl")

'''预测'''
pre_result = np.zeros(data_num)

for i in range(data_num):

    '''先编码'''
    pep_code = np.zeros((pep_len_max, amino_acid_num))
    HLA_code = np.zeros((HLA_len, amino_acid_num))

    for j in range(pep_len[i]):
        pep_code[j,:] = BLOSUM50_Matrix[pep_seq[i][j]]              #先对peptide编码

    for j in range(HLA_len):
        HLA_code[j,:] = BLOSUM50_Matrix[HLA_seq[i][j]]              #最后对HLA序列编码，放在后面
            
    pep_code = pep_code.reshape(-1, 1, embedding_dim)               #lstm input: shape = [seq_length, batch_size, input_size]的张量
    HLA_code = HLA_code.reshape(-1, 1, embedding_dim)               #batch_size = 1           

    '''前向传播，得到预测'''
    pep_code = torch.Tensor(pep_code).to(device)                    #输入GPU
    HLA_code = torch.Tensor(HLA_code).to(device)

    target = bind_label[i]
    target = target.reshape(-1,1)
    target = torch.Tensor(target).to(device, dtype = torch.float)   #MSE backward()中要求是float，不是long

    prediction = use_model(pep_code, HLA_code)
    pre_result[i] = prediction.item()

pre_result
# Out:
# array([ 9.62935746e-01,  1.04301977e+00,  1.04400420e+00,  9.70120728e-01,
#         1.09561634e+00,  1.12433875e+00,  1.02798307e+00,  1.12743664e+00,
#         1.03080666e+00,  1.04586267e+00,  1.17766654e+00,  1.15487838e+00,
#         1.12857795e+00,  1.05498564e+00,  1.05859959e+00,  1.02608180e+00,
#         1.06849670e+00,  1.04245710e+00,  9.74090636e-01,  1.00777149e+00,
#         8.96594346e-01,  7.71623433e-01,  8.00168157e-01,  7.93166399e-01])

# %%
'''probability--->binding(1) or non-binding(0)'''
pre_result[pre_result >= 0.5] = 1
pre_result[pre_result < 0.5] = 0

'''prediction与label比较'''
pre_result[pre_result != bind_label] = 0    #用pre_result保存比较结果
pre_result[pre_result == bind_label] = 1

correct_num = np.sum(pre_result)
accuracy = correct_num/data_num
print("accuracy on independent_set is {:.4f}".format(accuracy))
# Out:
# accuracy on independent_set is 0.9267

# %%
#external_set
'''BLOSUM50'''
BLOSUM50_Matrix = pd.read_table('BLOSUM50_Matrix.txt',sep = '\s+')          #用\s+,如果用\t会让txt中第一列会被当作数据
amino_acid_sort = ['A','R','N','D','C','Q','E','G','H','I','L','K','M','F','P','S','T','W','Y','V','B','J','Z','X']    #X可以用于padding
amino_acid_num = len(amino_acid_sort)
BLOSUM50_Matrix = BLOSUM50_Matrix.loc[amino_acid_sort, amino_acid_sort]     #去掉BLOSUM50中的*

'''提取数据'''
pep_data = pd.read_csv("data_csv/external_set2.csv",usecols=["peptide","length"]) 
HLA_data = pd.read_csv("data_csv/external_set2.csv",usecols=["HLA_sequence"]) 
bind_data = pd.read_csv("data_csv/external_set2.csv",usecols=["label"]) 

pep_seq, pep_len, pep_len_max= np.array(pep_data["peptide"]), np.array(pep_data["length"]), 14
HLA_seq, HLA_len = np.array(HLA_data["HLA_sequence"]), 34
bind_label = np.array(bind_data["label"])

data_num = bind_label.size          #数据数量

'''加载模型'''
use_model = torch.load("model/NetMHCpan_10_LSTM2_fold2.pkl")

'''预测'''
pre_result = np.zeros(data_num)

for i in range(data_num):

    '''先编码'''
    pep_code = np.zeros((pep_len_max, amino_acid_num))
    HLA_code = np.zeros((HLA_len, amino_acid_num))

    for j in range(pep_len[i]):
        pep_code[j,:] = BLOSUM50_Matrix[pep_seq[i][j]]              #先对peptide编码

    for j in range(HLA_len):
        HLA_code[j,:] = BLOSUM50_Matrix[HLA_seq[i][j]]              #最后对HLA序列编码，放在后面
            
    pep_code = pep_code.reshape(-1, 1, embedding_dim)               #lstm input: shape = [seq_length, batch_size, input_size]的张量
    HLA_code = HLA_code.reshape(-1, 1, embedding_dim)               #batch_size = 1           

    '''前向传播，得到预测'''
    pep_code = torch.Tensor(pep_code).to(device)                    #输入GPU
    HLA_code = torch.Tensor(HLA_code).to(device)

    target = bind_label[i]
    target = target.reshape(-1,1)
    target = torch.Tensor(target).to(device, dtype = torch.float)   #MSE backward()中要求是float，不是long

    prediction = use_model(pep_code, HLA_code)
    pre_result[i] = prediction.item()

'''probability--->binding(1) or non-binding(0)'''
pre_result[pre_result >= 0.5] = 1
pre_result[pre_result < 0.5] = 0

'''prediction与label比较'''
pre_result[pre_result != bind_label] = 0    #用pre_result保存比较结果
pre_result[pre_result == bind_label] = 1

correct_num = np.sum(pre_result)
accuracy = correct_num/data_num
print("accuracy on external_set is {}".format(accuracy))
# Out:
# accuracy on external_set is 0.927

# %% [markdown]
# 结果更好，进一步的，是不是可以将Matrix中与X相关的去掉？
